# %%
import json
import string
import random
from neo4j import GraphDatabase

uri = "bolt://localhost:7687"
user = "neo4j"
password = "12345678"
json_file_path = r"C:\Users\Tuba.Gokhan\Desktop\KG\filtered_COBS.json"  # Adjusted to the uploaded file path

class Neo4jConnection:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))
        self.used_ids = set()  # Set to keep track of used IDs
        self.document_title = None
        print("Connected to Neo4j.")

    def close(self):
        self.driver.close()
        print("Connection to Neo4j closed.")
        
    def clear_database(self):
        with self.driver.session(database="documents") as session:
            session.run("MATCH (n) DETACH DELETE n")
            self.used_ids.clear()
            print("Previous data deleted from the database.")

    def generate_unique_id(self, length=8):
        """Generate a unique ID of mixed characters and digits."""
        characters = string.ascii_letters + string.digits
        while True:
            unique_id = ''.join(random.choice(characters) for _ in range(length))
            if unique_id not in self.used_ids:
                self.used_ids.add(unique_id)
                return unique_id

    def create_paragraphs_and_obligations(self, document_title, document_version, document_date, data):
        self.clear_database()  # Clear previous data before inserting new data
        self.document_title = document_title  # Store document title for later reference
        with self.driver.session(database="documents") as session:
            # Create Document node with a unique ID
            doc_id = self.generate_unique_id()
            session.run("CREATE (:Document {id: $id, title: $title, version: $version, date: $date})", 
                        id=doc_id, title=document_title, version=document_version, date=document_date)
            print(f"Document node created with Title: {document_title}")
            
            for item in data:
                # Create Paragraph node with a unique ID
                para_id = self.generate_unique_id()
                session.run("CREATE (:Paragraph {id: $id, contextID: $contextID, text: $text})", 
                            id=para_id, contextID=item['ContextID'], text=item['Text'])
                
                # Create Obligation nodes and link them to the Paragraph node
                for obligation in item['Obligations']:
                    heading, description = self.parse_obligation_text(obligation)
                    obli_id = self.generate_unique_id()
                    session.run("""
                    MATCH (p:Paragraph {id: $para_id})
                    CREATE (o:Obligation {id: $obli_id, heading: $heading, description: $description})
                    MERGE (p)-[:HAS_OBLIGATION]->(o)
                    """, para_id=para_id, obli_id=obli_id, heading=heading, description=description)
                    #print(f"Obligation node created with ID: {obli_id}, linked to Paragraph ID: {para_id}")

        # After creating all nodes, establish CONTAINS relationships
        self.create_contains_relationships(data)

        
    def create_paragraphs_and_obligations(self, document_title, document_version, document_date, data):
        self.clear_database()  # Clear previous data before inserting new data
        self.document_title = document_title  # Store document title for later reference
        with self.driver.session(database="documents") as session:
            # Create Document node with a unique ID
            doc_id = self.generate_unique_id()
            session.run("CREATE (:Document {id: $id, title: $title, version: $version, date: $date})", 
                        id=doc_id, title=document_title, version=document_version, date=document_date)
            print(f"Document node created with Title: {document_title}")
    
            for item in data:
                if item['ContextID'].endswith('.'):
                    item['ContextID'] = item['ContextID'][:-1]
                # Create Paragraph node with a unique ID
                para_id = self.generate_unique_id()
                session.run("CREATE (p:Paragraph {id: $id, contextID: $contextID, text: $text}) RETURN p", 
                            id=para_id, contextID=item['ContextID'], text=item['Text'])
                
                # Determine parent ID (document or another paragraph)
                parent_context_id = '.'.join(item['ContextID'].split('.')[:-1])
                if parent_context_id:
                    # Link to parent paragraph
                    session.run("""
                    MATCH (parent:Paragraph {contextID: $parent_context_id}), (child:Paragraph {id: $para_id})
                    MERGE (parent)-[:CONTAINS]->(child)
                    """, parent_context_id=parent_context_id, para_id=para_id)
                    print(f"Paragraph node created with ContextID: {item['ContextID']}, linked to parent Paragraph ContextID: {parent_context_id}")
                else:
                    # Link directly to document
                    session.run("""
                    MATCH (doc:Document {id: $doc_id}), (para:Paragraph {id: $para_id})
                    MERGE (doc)-[:CONTAINS]->(para)
                    """, doc_id=doc_id, para_id=para_id)
                    print(f"Paragraph node created with ContextID: {item['ContextID']}, linked directly to Document")
    
                # Create Obligation nodes and link them to the Paragraph node
                for obligation in item['Obligations']:
                    heading, description = self.parse_obligation_text(obligation)
                    obli_id = self.generate_unique_id()
                    session.run("""
                    MATCH (p:Paragraph {id: $para_id})
                    CREATE (o:Obligation {id: $obli_id, heading: $heading, description: $description})
                    MERGE (p)-[:HAS_OBLIGATION]->(o)
                    """, para_id=para_id, obli_id=obli_id, heading=heading, description=description)
                    #print(f"Obligation node created with ID: {obli_id}, linked to Paragraph ID: {para_id}")



    def parse_obligation_text(self, text):
          # Remove the last character if it is a double quote
        if text.endswith('"'):
                text = text[:-1]
    
          # Check if ':**' is in the text
        if '**' in text:
                  # Find the start of the heading after ':**'
                  temp = text.split('**')
                  heading = temp[0].split('"')[1]
                  description = temp[1]
        else:
              # Find the first occurrence of a double quote and use the rest of the text as the heading
              try:
                  start_index = text.index(' \"') + 1  # Start after the first double quote
                  heading = description =  text[start_index:]  # Assign the rest of the text to heading
              except ValueError:
                  # Handle cases where the double quotes are not found or improperly formatted
                  heading = "Invalid format or missing double quotes"
                  description = ""
    
          # Remove leading double quotes from heading and description, if present
        
        if heading.endswith(':'):
            heading = heading[:-1]
        if heading.startswith('"'):
            heading = heading[1:]
        if description.startswith('"'):
            description = description[1:]
        if description.startswith(':'):
            description = description[1:]

          
        return heading, description

if __name__ == "__main__":
    conn = Neo4jConnection(uri, user, password)
    
    with open(json_file_path, 'r') as file:
        data = json.load(file)
    
    document_info = {
        "title": "Conduct of Business Rulebook (COBS)",
        "version": "VER15.150823",
        "date": "15/08/2023"
    }
    
    conn.create_paragraphs_and_obligations(document_info['title'], document_info['version'], document_info['date'], data)
    conn.close()
# Out:
# Connected to Neo4j.
# Previous data deleted from the database.
# Document node created with Title: Conduct of Business Rulebook (COBS)
# Paragraph node created with ContextID: 1, linked directly to Document
# Paragraph node created with ContextID: 1.1, linked to parent Paragraph ContextID: 1
# Paragraph node created with ContextID: 2, linked directly to Document
# Paragraph node created with ContextID: 2.1, linked to parent Paragraph ContextID: 2
# Paragraph node created with ContextID: 2.1.1, linked to parent Paragraph ContextID: 2.1
# Paragraph node created with ContextID: 2.1.2, linked to parent Paragraph ContextID: 2.1
# Paragraph node created with ContextID: 2.1.3, linked to parent Paragraph ContextID: 2.1
# Paragraph node created with ContextID: 2.1.3.Guidance, linked to parent Paragraph ContextID: 2.1.3
# Paragraph node created with ContextID: 2.1.3.Guidance.1, linked to parent Paragraph ContextID: 2.1.3.Guidance
# Paragraph node created with ContextID: 2.1.3.Guidance.2, linked to parent Paragraph ContextID: 2.1.3.Guidance
# Paragraph node created with ContextID: 2.2, linked to parent Paragraph ContextID: 2
# Paragraph node created with ContextID: 2.2.1, linked to parent Paragraph ContextID: 2.2
# Paragraph node created with ContextID: 2.2.2, linked to parent Paragraph ContextID: 2.2
# Paragraph node created with ContextID: 2.2.2.Guidance, linked to parent Paragraph ContextID: 2.2.2
# Paragraph node created with ContextID: 2.2.2.Guidance.1, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Paragraph node created with ContextID: 2.2.2.Guidance.2, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Paragraph node created with ContextID: 2.2.2.Guidance.3, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Paragraph node created with ContextID: 2.2.2.Guidance.4, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Paragraph node created with ContextID: 2.2.2.Guidance.5, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Paragraph node created with ContextID: 2.2.3, linked to parent Paragraph ContextID: 2.2
# Paragraph node created with ContextID: 2.2.4, linked to parent Paragraph ContextID: 2.2
# Paragraph node created with ContextID: 2.3, linked to parent Paragraph ContextID: 2
# Paragraph node created with ContextID: 2.4, linked to parent Paragraph ContextID: 2
# Paragraph node created with ContextID: 2.4.1, linked to parent Paragraph ContextID: 2.4
# Paragraph node created with ContextID: 2.4.1.Guidance, linked to parent Paragraph ContextID: 2.4.1
# Paragraph node created with ContextID: 2.4.1.Guidance.1, linked to parent Paragraph ContextID: 2.4.1.Guidance
# Paragraph node created with ContextID: 2.4.1.Guidance.2, linked to parent Paragraph ContextID: 2.4.1.Guidance
# Paragraph node created with ContextID: 2.4.2, linked to parent Paragraph ContextID: 2.4
# Paragraph node created with ContextID: 2.4.2.(a), linked to parent Paragraph ContextID: 2.4.2
# Paragraph node created with ContextID: 2.4.2.(b), linked to parent Paragraph ContextID: 2.4.2
# Paragraph node created with ContextID: 2.4.3, linked to parent Paragraph ContextID: 2.4
# Paragraph node created with ContextID: 2.4.4, linked to parent Paragraph ContextID: 2.4
# Paragraph node created with ContextID: 2.4.4.Individuals, linked to parent Paragraph ContextID: 2.4.4
# Paragraph node created with ContextID: 2.4.4.Individuals.(a), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Paragraph node created with ContextID: 2.4.4.Individuals.(b), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Paragraph node created with ContextID: 2.4.4.Individuals.(c), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Paragraph node created with ContextID: 2.4.4.Individuals.(d), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Paragraph node created with ContextID: 2.4.4.Individuals.(e), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Paragraph node created with ContextID: 2.4.4.Individuals.Guidance, linked to parent Paragraph ContextID: 2.4.4.Individuals
# Paragraph node created with ContextID: 2.4.4.Individuals.Guidance.1, linked to parent Paragraph ContextID: 2.4.4.Individuals.Guidance
# Paragraph node created with ContextID: 2.4.4.Individuals.Guidance.2, linked to parent Paragraph ContextID: 2.4.4.Individuals.Guidance
# Paragraph node created with ContextID: 2.4.4.Undertakings, linked to parent Paragraph ContextID: 2.4.4
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance, linked to parent Paragraph ContextID: 2.4.4.Undertakings
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance.1, linked to parent Paragraph ContextID: 2.4.4.Undertakings.Guidance
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance.2, linked to parent Paragraph ContextID: 2.4.4.Undertakings.Guidance
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance.3, linked to parent Paragraph ContextID: 2.4.4.Undertakings.Guidance
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance.4, linked to parent Paragraph ContextID: 2.4.4.Undertakings.Guidance
# Paragraph node created with ContextID: 2.5, linked to parent Paragraph ContextID: 2
# Paragraph node created with ContextID: 2.5.(a), linked to parent Paragraph ContextID: 2.5
# Paragraph node created with ContextID: 2.5.(b), linked to parent Paragraph ContextID: 2.5
# Paragraph node created with ContextID: 2.6, linked to parent Paragraph ContextID: 2
# Paragraph node created with ContextID: 2.6.1, linked to parent Paragraph ContextID: 2.6
# Paragraph node created with ContextID: 2.6.1.(a), linked to parent Paragraph ContextID: 2.6.1
# Paragraph node created with ContextID: 2.6.1.(b), linked to parent Paragraph ContextID: 2.6.1
# Paragraph node created with ContextID: 2.6.1.(c), linked to parent Paragraph ContextID: 2.6.1
# Paragraph node created with ContextID: 2.6.1.(d), linked to parent Paragraph ContextID: 2.6.1
# Paragraph node created with ContextID: 2.6.1.Guidance, linked to parent Paragraph ContextID: 2.6.1
# Paragraph node created with ContextID: 2.6.1.Guidance.1, linked to parent Paragraph ContextID: 2.6.1.Guidance
# Paragraph node created with ContextID: 2.6.1.Guidance.2, linked to parent Paragraph ContextID: 2.6.1.Guidance
# Paragraph node created with ContextID: 2.6.1.Guidance.3, linked to parent Paragraph ContextID: 2.6.1.Guidance
# Paragraph node created with ContextID: 2.6.2, linked to parent Paragraph ContextID: 2.6
# Paragraph node created with ContextID: 2.6.2.(a), linked to parent Paragraph ContextID: 2.6.2
# Paragraph node created with ContextID: 2.6.2.(b), linked to parent Paragraph ContextID: 2.6.2
# Paragraph node created with ContextID: 2.6.3, linked to parent Paragraph ContextID: 2.6
# Paragraph node created with ContextID: 2.6.3.(a), linked to parent Paragraph ContextID: 2.6.3
# Paragraph node created with ContextID: 2.6.3.(b), linked to parent Paragraph ContextID: 2.6.3
# Paragraph node created with ContextID: 2.6.3.Guidance, linked to parent Paragraph ContextID: 2.6.3
# Paragraph node created with ContextID: 2.6.3.Guidance.1, linked to parent Paragraph ContextID: 2.6.3.Guidance
# Paragraph node created with ContextID: 2.6.3.Guidance.2, linked to parent Paragraph ContextID: 2.6.3.Guidance
# Paragraph node created with ContextID: 2.6.4, linked to parent Paragraph ContextID: 2.6
# Paragraph node created with ContextID: 2.6.4.Guidance, linked to parent Paragraph ContextID: 2.6.4
# Paragraph node created with ContextID: 2.6.4.Guidance.1, linked to parent Paragraph ContextID: 2.6.4.Guidance
# Paragraph node created with ContextID: 2.6.4.Guidance.3, linked to parent Paragraph ContextID: 2.6.4.Guidance
# Paragraph node created with ContextID: 2.6.4.Guidance.4, linked to parent Paragraph ContextID: 2.6.4.Guidance
# Paragraph node created with ContextID: 2.7, linked to parent Paragraph ContextID: 2
# Paragraph node created with ContextID: 2.7.1, linked to parent Paragraph ContextID: 2.7
# Paragraph node created with ContextID: 2.7.2, linked to parent Paragraph ContextID: 2.7
# Paragraph node created with ContextID: 2.7.3, linked to parent Paragraph ContextID: 2.7
# Paragraph node created with ContextID: 2.7.4, linked to parent Paragraph ContextID: 2.7
# Paragraph node created with ContextID: 2.7.5, linked to parent Paragraph ContextID: 2.7
# Paragraph node created with ContextID: 3.2, linked to parent Paragraph ContextID: 3
# Paragraph node created with ContextID: 3.2.1, linked to parent Paragraph ContextID: 3.2
# Paragraph node created with ContextID: 3.2.1.Guidance, linked to parent Paragraph ContextID: 3.2.1
# Paragraph node created with ContextID: 3.2.1.Guidance.1, linked to parent Paragraph ContextID: 3.2.1.Guidance
# Paragraph node created with ContextID: 3.2.2, linked to parent Paragraph ContextID: 3.2
# Paragraph node created with ContextID: 3.2.3, linked to parent Paragraph ContextID: 3.2
# Paragraph node created with ContextID: 3.2.4.(a), linked to parent Paragraph ContextID: 3.2.4
# Paragraph node created with ContextID: 3.2.4.(a).Guidance, linked to parent Paragraph ContextID: 3.2.4.(a)
# Paragraph node created with ContextID: 3.2.4.(a).Guidance.1, linked to parent Paragraph ContextID: 3.2.4.(a).Guidance
# Paragraph node created with ContextID: 3.2.4.(b), linked to parent Paragraph ContextID: 3.2.4
# Paragraph node created with ContextID: 3.2.4.(b).Guidance, linked to parent Paragraph ContextID: 3.2.4.(b)
# Paragraph node created with ContextID: 3.2.5, linked to parent Paragraph ContextID: 3.2
# Paragraph node created with ContextID: 3.2.6, linked to parent Paragraph ContextID: 3.2
# Paragraph node created with ContextID: 3.3, linked to parent Paragraph ContextID: 3
# Paragraph node created with ContextID: 3.3.1, linked to parent Paragraph ContextID: 3.3
# Paragraph node created with ContextID: 3.3.2, linked to parent Paragraph ContextID: 3.3
# Paragraph node created with ContextID: 3.3.2.(a), linked to parent Paragraph ContextID: 3.3.2
# Paragraph node created with ContextID: 3.3.2.(b), linked to parent Paragraph ContextID: 3.3.2
# Paragraph node created with ContextID: 3.3.2.(c), linked to parent Paragraph ContextID: 3.3.2
# Paragraph node created with ContextID: 3.3.3, linked to parent Paragraph ContextID: 3.3
# Paragraph node created with ContextID: 3.3.3.Guidance, linked to parent Paragraph ContextID: 3.3.3
# Paragraph node created with ContextID: 3.3.3.Guidance.1, linked to parent Paragraph ContextID: 3.3.3.Guidance
# Paragraph node created with ContextID: 3.3.3.Guidance.2, linked to parent Paragraph ContextID: 3.3.3.Guidance
# Paragraph node created with ContextID: 3.3.3.Guidance.3, linked to parent Paragraph ContextID: 3.3.3.Guidance
# Paragraph node created with ContextID: 3.3.4, linked to parent Paragraph ContextID: 3.3
# Paragraph node created with ContextID: 3.4, linked to parent Paragraph ContextID: 3
# Paragraph node created with ContextID: 3.4.1, linked to parent Paragraph ContextID: 3.4
# Paragraph node created with ContextID: 3.4.2, linked to parent Paragraph ContextID: 3.4
# Paragraph node created with ContextID: 3.4.2.(a), linked to parent Paragraph ContextID: 3.4.2
# Paragraph node created with ContextID: 3.4.2.(b), linked to parent Paragraph ContextID: 3.4.2
# Paragraph node created with ContextID: 3.4.2.(c), linked to parent Paragraph ContextID: 3.4.2
# Paragraph node created with ContextID: 3.4.2.(d), linked to parent Paragraph ContextID: 3.4.2
# Paragraph node created with ContextID: 3.4.2.(e), linked to parent Paragraph ContextID: 3.4.2
# Paragraph node created with ContextID: 3.4.3, linked to parent Paragraph ContextID: 3.4
# Paragraph node created with ContextID: 3.5, linked to parent Paragraph ContextID: 3
# Paragraph node created with ContextID: 3.5.1, linked to parent Paragraph ContextID: 3.5
# Paragraph node created with ContextID: 3.5.2, linked to parent Paragraph ContextID: 3.5
# Paragraph node created with ContextID: 3.5.3, linked to parent Paragraph ContextID: 3.5
# Paragraph node created with ContextID: 3.5.4, linked to parent Paragraph ContextID: 3.5
# Paragraph node created with ContextID: 3.5.4.(a), linked to parent Paragraph ContextID: 3.5.4
# Paragraph node created with ContextID: 3.5.4.(b), linked to parent Paragraph ContextID: 3.5.4
# Paragraph node created with ContextID: 3.5.5, linked to parent Paragraph ContextID: 3.5
# Paragraph node created with ContextID: 3.5.5.(a), linked to parent Paragraph ContextID: 3.5.5
# Paragraph node created with ContextID: 3.5.5.(b), linked to parent Paragraph ContextID: 3.5.5
# Paragraph node created with ContextID: 3.5.5.Guidance, linked to parent Paragraph ContextID: 3.5.5
# Paragraph node created with ContextID: 3.5.6, linked to parent Paragraph ContextID: 3.5
# Paragraph node created with ContextID: 3.5.7, linked to parent Paragraph ContextID: 3.5
# Paragraph node created with ContextID: 3.5.8, linked to parent Paragraph ContextID: 3.5
# Paragraph node created with ContextID: 3.5.8.(a), linked to parent Paragraph ContextID: 3.5.8
# Paragraph node created with ContextID: 3.5.8.(b), linked to parent Paragraph ContextID: 3.5.8
# Paragraph node created with ContextID: 3.5.8.(c), linked to parent Paragraph ContextID: 3.5.8
# Paragraph node created with ContextID: 3.6, linked to parent Paragraph ContextID: 3
# Paragraph node created with ContextID: 3.6.1, linked to parent Paragraph ContextID: 3.6
# Paragraph node created with ContextID: 3.6.2, linked to parent Paragraph ContextID: 3.6
# Paragraph node created with ContextID: 3.6.3, linked to parent Paragraph ContextID: 3.6
# Paragraph node created with ContextID: 3.6.4, linked to parent Paragraph ContextID: 3.6
# Paragraph node created with ContextID: 3.6.5, linked to parent Paragraph ContextID: 3.6
# Paragraph node created with ContextID: 3.6.6, linked to parent Paragraph ContextID: 3.6
# Paragraph node created with ContextID: 3.7, linked to parent Paragraph ContextID: 3
# Paragraph node created with ContextID: 3.7.1, linked to parent Paragraph ContextID: 3.7
# Paragraph node created with ContextID: 3.7.2, linked to parent Paragraph ContextID: 3.7
# Paragraph node created with ContextID: 3.8, linked to parent Paragraph ContextID: 3
# Paragraph node created with ContextID: 3.8.1, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.1.Guidance, linked to parent Paragraph ContextID: 3.8.1
# Paragraph node created with ContextID: 3.8.1.Guidance.1, linked to parent Paragraph ContextID: 3.8.1.Guidance
# Paragraph node created with ContextID: 3.8.1.Guidance.2, linked to parent Paragraph ContextID: 3.8.1.Guidance
# Paragraph node created with ContextID: 3.8.1.Guidance.3, linked to parent Paragraph ContextID: 3.8.1.Guidance
# Paragraph node created with ContextID: 3.8.2, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.3, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.3.Guidance, linked to parent Paragraph ContextID: 3.8.3
# Paragraph node created with ContextID: 3.8.3.Guidance.1, linked to parent Paragraph ContextID: 3.8.3.Guidance
# Paragraph node created with ContextID: 3.8.4, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.5, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.5.Guidance, linked to parent Paragraph ContextID: 3.8.5
# Paragraph node created with ContextID: 3.8.5.Guidance.1, linked to parent Paragraph ContextID: 3.8.5.Guidance
# Paragraph node created with ContextID: 3.8.5.Guidance.2, linked to parent Paragraph ContextID: 3.8.5.Guidance
# Paragraph node created with ContextID: 3.8.5.Guidance.3, linked to parent Paragraph ContextID: 3.8.5.Guidance
# Paragraph node created with ContextID: 3.8.6, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.6.Guidance, linked to parent Paragraph ContextID: 3.8.6
# Paragraph node created with ContextID: 3.8.6.Guidance.1, linked to parent Paragraph ContextID: 3.8.6.Guidance
# Paragraph node created with ContextID: 3.8.6.Guidance.2, linked to parent Paragraph ContextID: 3.8.6.Guidance
# Paragraph node created with ContextID: 3.8.7, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.8, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.8.Guidance, linked to parent Paragraph ContextID: 3.8.8
# Paragraph node created with ContextID: 3.8.9, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.10, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.11, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.11.Guidance, linked to parent Paragraph ContextID: 3.8.11
# Paragraph node created with ContextID: 3.8.11.Guidance.1, linked to parent Paragraph ContextID: 3.8.11.Guidance
# Paragraph node created with ContextID: 3.8.12, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.12.Guidance, linked to parent Paragraph ContextID: 3.8.12
# Paragraph node created with ContextID: 3.8.12.Guidance.1, linked to parent Paragraph ContextID: 3.8.12.Guidance
# Paragraph node created with ContextID: 3.8.12.Guidance.2, linked to parent Paragraph ContextID: 3.8.12.Guidance
# Paragraph node created with ContextID: 3.8.12.Guidance.3, linked to parent Paragraph ContextID: 3.8.12.Guidance
# Paragraph node created with ContextID: 3.8.12.Guidance.4, linked to parent Paragraph ContextID: 3.8.12.Guidance
# Paragraph node created with ContextID: 3.8.13, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.14, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.15, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.16, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.16.Guidance, linked to parent Paragraph ContextID: 3.8.16
# Paragraph node created with ContextID: 3.8.16.Guidance.1, linked to parent Paragraph ContextID: 3.8.16.Guidance
# Paragraph node created with ContextID: 3.8.17, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.18, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.18.Guidance, linked to parent Paragraph ContextID: 3.8.18
# Paragraph node created with ContextID: 3.8.18.Guidance.1, linked to parent Paragraph ContextID: 3.8.18.Guidance
# Paragraph node created with ContextID: 3.8.19, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.20, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.21, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.22, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.22.Guidance, linked to parent Paragraph ContextID: 3.8.22
# Paragraph node created with ContextID: 3.8.22.Guidance.1, linked to parent Paragraph ContextID: 3.8.22.Guidance
# Paragraph node created with ContextID: 3.8.23, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.24, linked to parent Paragraph ContextID: 3.8
# Paragraph node created with ContextID: 3.8.24.Guidance, linked to parent Paragraph ContextID: 3.8.24
# Paragraph node created with ContextID: 3.8.24.Guidance.1, linked to parent Paragraph ContextID: 3.8.24.Guidance
# Paragraph node created with ContextID: 4, linked directly to Document
# Paragraph node created with ContextID: 4.1, linked to parent Paragraph ContextID: 4
# Paragraph node created with ContextID: 4.1.1, linked to parent Paragraph ContextID: 4.1
# Paragraph node created with ContextID: 4.2, linked to parent Paragraph ContextID: 4
# Paragraph node created with ContextID: 4.2.1.(1), linked to parent Paragraph ContextID: 4.2.1
# Paragraph node created with ContextID: 4.2.1.(2), linked to parent Paragraph ContextID: 4.2.1
# Paragraph node created with ContextID: 4.3, linked to parent Paragraph ContextID: 4
# Paragraph node created with ContextID: 4.3.1, linked to parent Paragraph ContextID: 4.3
# Paragraph node created with ContextID: 4.3.2, linked to parent Paragraph ContextID: 4.3
# Paragraph node created with ContextID: 4.3.3.(a), linked to parent Paragraph ContextID: 4.3.3
# Paragraph node created with ContextID: 4.3.3.(b), linked to parent Paragraph ContextID: 4.3.3
# Paragraph node created with ContextID: 4.3.3.(b).Guidance, linked to parent Paragraph ContextID: 4.3.3.(b)
# Paragraph node created with ContextID: 4.4, linked to parent Paragraph ContextID: 4
# Paragraph node created with ContextID: 4.4.1.(a), linked to parent Paragraph ContextID: 4.4.1
# Paragraph node created with ContextID: 4.4.1.(b), linked to parent Paragraph ContextID: 4.4.1
# Paragraph node created with ContextID: 5, linked directly to Document
# Paragraph node created with ContextID: 5.1, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.1.1, linked to parent Paragraph ContextID: 5.1
# Paragraph node created with ContextID: 5.2, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.2.1, linked to parent Paragraph ContextID: 5.2
# Paragraph node created with ContextID: 5.2.2, linked to parent Paragraph ContextID: 5.2
# Paragraph node created with ContextID: 5.2.3, linked to parent Paragraph ContextID: 5.2
# Paragraph node created with ContextID: 5.2.4, linked to parent Paragraph ContextID: 5.2
# Paragraph node created with ContextID: 5.3, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.3.1, linked to parent Paragraph ContextID: 5.3
# Paragraph node created with ContextID: 5.3.2, linked to parent Paragraph ContextID: 5.3
# Paragraph node created with ContextID: 5.3.3, linked to parent Paragraph ContextID: 5.3
# Paragraph node created with ContextID: 5.4, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.4.1, linked to parent Paragraph ContextID: 5.4
# Paragraph node created with ContextID: 5.5, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.5.1, linked to parent Paragraph ContextID: 5.5
# Paragraph node created with ContextID: 5.6, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.6.1, linked to parent Paragraph ContextID: 5.6
# Paragraph node created with ContextID: 5.6.2, linked to parent Paragraph ContextID: 5.6
# Paragraph node created with ContextID: 5.6.3, linked to parent Paragraph ContextID: 5.6
# Paragraph node created with ContextID: 5.7, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.7.1, linked to parent Paragraph ContextID: 5.7
# Paragraph node created with ContextID: 5.7.2, linked to parent Paragraph ContextID: 5.7
# Paragraph node created with ContextID: 5.8, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.9, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.9.1, linked to parent Paragraph ContextID: 5.9
# Paragraph node created with ContextID: 5.9.2, linked to parent Paragraph ContextID: 5.9
# Paragraph node created with ContextID: 5.10, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.10.1, linked to parent Paragraph ContextID: 5.10
# Paragraph node created with ContextID: 5.10.2, linked to parent Paragraph ContextID: 5.10
# Paragraph node created with ContextID: 5.10.3, linked to parent Paragraph ContextID: 5.10
# Paragraph node created with ContextID: 5.10.4, linked to parent Paragraph ContextID: 5.10
# Paragraph node created with ContextID: 5.11, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.11.1, linked to parent Paragraph ContextID: 5.11
# Paragraph node created with ContextID: 5.11.2, linked to parent Paragraph ContextID: 5.11
# Paragraph node created with ContextID: 5.11.3, linked to parent Paragraph ContextID: 5.11
# Paragraph node created with ContextID: 5.11.4, linked to parent Paragraph ContextID: 5.11
# Paragraph node created with ContextID: 5.12, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.12.1, linked to parent Paragraph ContextID: 5.12
# Paragraph node created with ContextID: 5.12.2, linked to parent Paragraph ContextID: 5.12
# Paragraph node created with ContextID: 5.13, linked to parent Paragraph ContextID: 5
# Paragraph node created with ContextID: 5.13.1, linked to parent Paragraph ContextID: 5.13
# Paragraph node created with ContextID: 5.13.2, linked to parent Paragraph ContextID: 5.13
# Paragraph node created with ContextID: 5.13.3, linked to parent Paragraph ContextID: 5.13
# Paragraph node created with ContextID: 5.13.4, linked to parent Paragraph ContextID: 5.13
# Paragraph node created with ContextID: 5.13.5, linked to parent Paragraph ContextID: 5.13
# Paragraph node created with ContextID: 6, linked directly to Document
# Paragraph node created with ContextID: 6.1, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.2, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.2.1, linked to parent Paragraph ContextID: 6.2
# Paragraph node created with ContextID: 6.2.2, linked to parent Paragraph ContextID: 6.2
# Paragraph node created with ContextID: 6.2.3, linked to parent Paragraph ContextID: 6.2
# Paragraph node created with ContextID: 6.2.4, linked to parent Paragraph ContextID: 6.2
# Paragraph node created with ContextID: 6.3, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.3.1.(a), linked to parent Paragraph ContextID: 6.3.1
# Paragraph node created with ContextID: 6.3.1.(b), linked to parent Paragraph ContextID: 6.3.1
# Paragraph node created with ContextID: 6.3.1.(b).Guidance, linked to parent Paragraph ContextID: 6.3.1.(b)
# Paragraph node created with ContextID: 6.4, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.4.1, linked to parent Paragraph ContextID: 6.4
# Paragraph node created with ContextID: 6.4.1.(a), linked to parent Paragraph ContextID: 6.4.1
# Paragraph node created with ContextID: 6.4.1.(b), linked to parent Paragraph ContextID: 6.4.1
# Paragraph node created with ContextID: 6.4.1.(c), linked to parent Paragraph ContextID: 6.4.1
# Paragraph node created with ContextID: 6.4.1.(c).Guidance, linked to parent Paragraph ContextID: 6.4.1.(c)
# Paragraph node created with ContextID: 6.4.2, linked to parent Paragraph ContextID: 6.4
# Paragraph node created with ContextID: 6.4.2.(a), linked to parent Paragraph ContextID: 6.4.2
# Paragraph node created with ContextID: 6.4.2.(b), linked to parent Paragraph ContextID: 6.4.2
# Paragraph node created with ContextID: 6.4.2.(c), linked to parent Paragraph ContextID: 6.4.2
# Paragraph node created with ContextID: 6.4.2.(c).Guidance, linked to parent Paragraph ContextID: 6.4.2.(c)
# Paragraph node created with ContextID: 6.4.3, linked to parent Paragraph ContextID: 6.4
# Paragraph node created with ContextID: 6.4.3.Guidance, linked to parent Paragraph ContextID: 6.4.3
# Paragraph node created with ContextID: 6.4.3.Guidance.1, linked to parent Paragraph ContextID: 6.4.3.Guidance
# Paragraph node created with ContextID: 6.4.4, linked to parent Paragraph ContextID: 6.4
# Paragraph node created with ContextID: 6.4.4.(a), linked to parent Paragraph ContextID: 6.4.4
# Paragraph node created with ContextID: 6.4.4.(b), linked to parent Paragraph ContextID: 6.4.4
# Paragraph node created with ContextID: 6.4.4.(b).Guidance, linked to parent Paragraph ContextID: 6.4.4.(b)
# Paragraph node created with ContextID: 6.4.4.(b).Guidance.1, linked to parent Paragraph ContextID: 6.4.4.(b).Guidance
# Paragraph node created with ContextID: 6.4.5, linked to parent Paragraph ContextID: 6.4
# Paragraph node created with ContextID: 6.4.6, linked to parent Paragraph ContextID: 6.4
# Paragraph node created with ContextID: 6.4.6.(a), linked to parent Paragraph ContextID: 6.4.6
# Paragraph node created with ContextID: 6.4.6.(a).Guidance, linked to parent Paragraph ContextID: 6.4.6.(a)
# Paragraph node created with ContextID: 6.4.6.(a).Guidance.1, linked to parent Paragraph ContextID: 6.4.6.(a).Guidance
# Paragraph node created with ContextID: 6.5, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.5.1, linked to parent Paragraph ContextID: 6.5
# Paragraph node created with ContextID: 6.5.1.(a), linked to parent Paragraph ContextID: 6.5.1
# Paragraph node created with ContextID: 6.5.1.(b), linked to parent Paragraph ContextID: 6.5.1
# Paragraph node created with ContextID: 6.5.2, linked to parent Paragraph ContextID: 6.5
# Paragraph node created with ContextID: 6.5.2.Guidance, linked to parent Paragraph ContextID: 6.5.2
# Paragraph node created with ContextID: 6.5.2.Guidance.1, linked to parent Paragraph ContextID: 6.5.2.Guidance
# Paragraph node created with ContextID: 6.5.3, linked to parent Paragraph ContextID: 6.5
# Paragraph node created with ContextID: 6.5.4, linked to parent Paragraph ContextID: 6.5
# Paragraph node created with ContextID: 6.5.5, linked to parent Paragraph ContextID: 6.5
# Paragraph node created with ContextID: 6.6, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.6.1, linked to parent Paragraph ContextID: 6.6
# Paragraph node created with ContextID: 6.6.1.Guidance, linked to parent Paragraph ContextID: 6.6.1
# Paragraph node created with ContextID: 6.6.1.Guidance.1, linked to parent Paragraph ContextID: 6.6.1.Guidance
# Paragraph node created with ContextID: 6.6.1.Guidance.2, linked to parent Paragraph ContextID: 6.6.1.Guidance
# Paragraph node created with ContextID: 6.7, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.7.1, linked to parent Paragraph ContextID: 6.7
# Paragraph node created with ContextID: 6.7.2, linked to parent Paragraph ContextID: 6.7
# Paragraph node created with ContextID: 6.7.3, linked to parent Paragraph ContextID: 6.7
# Paragraph node created with ContextID: 6.8, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.8.1, linked to parent Paragraph ContextID: 6.8
# Paragraph node created with ContextID: 6.8.1.(a), linked to parent Paragraph ContextID: 6.8.1
# Paragraph node created with ContextID: 6.8.1.(b), linked to parent Paragraph ContextID: 6.8.1
# Paragraph node created with ContextID: 6.8.1.(c), linked to parent Paragraph ContextID: 6.8.1
# Paragraph node created with ContextID: 6.8.1.(c).Guidance, linked to parent Paragraph ContextID: 6.8.1.(c)
# Paragraph node created with ContextID: 6.8.1.(c).Guidance.1, linked to parent Paragraph ContextID: 6.8.1.(c).Guidance
# Paragraph node created with ContextID: 6.8.1.(c).Guidance.2, linked to parent Paragraph ContextID: 6.8.1.(c).Guidance
# Paragraph node created with ContextID: 6.8.2, linked to parent Paragraph ContextID: 6.8
# Paragraph node created with ContextID: 6.8.2.(a), linked to parent Paragraph ContextID: 6.8.2
# Paragraph node created with ContextID: 6.8.2.(b), linked to parent Paragraph ContextID: 6.8.2
# Paragraph node created with ContextID: 6.8.2.(c), linked to parent Paragraph ContextID: 6.8.2
# Paragraph node created with ContextID: 6.8.2.(d), linked to parent Paragraph ContextID: 6.8.2
# Paragraph node created with ContextID: 6.9, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.9.1, linked to parent Paragraph ContextID: 6.9
# Paragraph node created with ContextID: 6.9.2, linked to parent Paragraph ContextID: 6.9
# Paragraph node created with ContextID: 6.9.2.(a), linked to parent Paragraph ContextID: 6.9.2
# Paragraph node created with ContextID: 6.9.2.(b), linked to parent Paragraph ContextID: 6.9.2
# Paragraph node created with ContextID: 6.9.3, linked to parent Paragraph ContextID: 6.9
# Paragraph node created with ContextID: 6.9.3.(a), linked to parent Paragraph ContextID: 6.9.3
# Paragraph node created with ContextID: 6.9.3.(b), linked to parent Paragraph ContextID: 6.9.3
# Paragraph node created with ContextID: 6.9.4, linked to parent Paragraph ContextID: 6.9
# Paragraph node created with ContextID: 6.9.5, linked to parent Paragraph ContextID: 6.9
# Paragraph node created with ContextID: 6.9.5.(a), linked to parent Paragraph ContextID: 6.9.5
# Paragraph node created with ContextID: 6.9.5.(b), linked to parent Paragraph ContextID: 6.9.5
# Paragraph node created with ContextID: 6.9.6, linked to parent Paragraph ContextID: 6.9
# Paragraph node created with ContextID: 6.9.6.(a), linked to parent Paragraph ContextID: 6.9.6
# Paragraph node created with ContextID: 6.9.6.(b), linked to parent Paragraph ContextID: 6.9.6
# Paragraph node created with ContextID: 6.10, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.10.1, linked to parent Paragraph ContextID: 6.10
# Paragraph node created with ContextID: 6.10.2, linked to parent Paragraph ContextID: 6.10
# Paragraph node created with ContextID: 6.10.2.(a), linked to parent Paragraph ContextID: 6.10.2
# Paragraph node created with ContextID: 6.10.2.(b), linked to parent Paragraph ContextID: 6.10.2
# Paragraph node created with ContextID: 6.10.2.(c), linked to parent Paragraph ContextID: 6.10.2
# Paragraph node created with ContextID: 6.10.3, linked to parent Paragraph ContextID: 6.10
# Paragraph node created with ContextID: 6.11, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.11.1, linked to parent Paragraph ContextID: 6.11
# Paragraph node created with ContextID: 6.11.2, linked to parent Paragraph ContextID: 6.11
# Paragraph node created with ContextID: 6.11.2.(a), linked to parent Paragraph ContextID: 6.11.2
# Paragraph node created with ContextID: 6.11.2.(b), linked to parent Paragraph ContextID: 6.11.2
# Paragraph node created with ContextID: 6.11.3, linked to parent Paragraph ContextID: 6.11
# Paragraph node created with ContextID: 6.12, linked to parent Paragraph ContextID: 6
# Paragraph node created with ContextID: 6.12.1, linked to parent Paragraph ContextID: 6.12
# Paragraph node created with ContextID: 6.12.2, linked to parent Paragraph ContextID: 6.12
# Paragraph node created with ContextID: 6.12.3, linked to parent Paragraph ContextID: 6.12
# Paragraph node created with ContextID: 6.12.3.Guidance, linked to parent Paragraph ContextID: 6.12.3
# Paragraph node created with ContextID: 6.12.3.Guidance.1, linked to parent Paragraph ContextID: 6.12.3.Guidance
# Paragraph node created with ContextID: 7, linked directly to Document
# Paragraph node created with ContextID: 7.1, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.2, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.2.1, linked to parent Paragraph ContextID: 7.2
# Paragraph node created with ContextID: 7.2.2, linked to parent Paragraph ContextID: 7.2
# Paragraph node created with ContextID: 7.2.3, linked to parent Paragraph ContextID: 7.2
# Paragraph node created with ContextID: 7.2.4, linked to parent Paragraph ContextID: 7.2
# Paragraph node created with ContextID: 7.2.5, linked to parent Paragraph ContextID: 7.2
# Paragraph node created with ContextID: 7.2.6, linked to parent Paragraph ContextID: 7.2
# Paragraph node created with ContextID: 7.2.6.Guidance, linked to parent Paragraph ContextID: 7.2.6
# Paragraph node created with ContextID: 7.2.6.Guidance.1, linked to parent Paragraph ContextID: 7.2.6.Guidance
# Paragraph node created with ContextID: 7.2.6.Guidance.2, linked to parent Paragraph ContextID: 7.2.6.Guidance
# Paragraph node created with ContextID: 7.2.6.Guidance.3, linked to parent Paragraph ContextID: 7.2.6.Guidance
# Paragraph node created with ContextID: 7.3, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.3.1, linked to parent Paragraph ContextID: 7.3
# Paragraph node created with ContextID: 7.3.1.(a), linked to parent Paragraph ContextID: 7.3.1
# Paragraph node created with ContextID: 7.3.1.(b), linked to parent Paragraph ContextID: 7.3.1
# Paragraph node created with ContextID: 7.3.1.(c), linked to parent Paragraph ContextID: 7.3.1
# Paragraph node created with ContextID: 7.3.1.(c).Guidance, linked to parent Paragraph ContextID: 7.3.1.(c)
# Paragraph node created with ContextID: 7.3.1.(c).Guidance.1, linked to parent Paragraph ContextID: 7.3.1.(c).Guidance
# Paragraph node created with ContextID: 7.4, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.4.1, linked to parent Paragraph ContextID: 7.4
# Paragraph node created with ContextID: 7.4.2, linked to parent Paragraph ContextID: 7.4
# Paragraph node created with ContextID: 7.4.3, linked to parent Paragraph ContextID: 7.4
# Paragraph node created with ContextID: 7.5, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.5.1, linked to parent Paragraph ContextID: 7.5
# Paragraph node created with ContextID: 7.5.2, linked to parent Paragraph ContextID: 7.5
# Paragraph node created with ContextID: 7.5.3, linked to parent Paragraph ContextID: 7.5
# Paragraph node created with ContextID: 7.5.4, linked to parent Paragraph ContextID: 7.5
# Paragraph node created with ContextID: 7.5.5, linked to parent Paragraph ContextID: 7.5
# Paragraph node created with ContextID: 7.5.6, linked to parent Paragraph ContextID: 7.5
# Paragraph node created with ContextID: 7.6, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.6.1, linked to parent Paragraph ContextID: 7.6
# Paragraph node created with ContextID: 7.6.2, linked to parent Paragraph ContextID: 7.6
# Paragraph node created with ContextID: 7.6.3, linked to parent Paragraph ContextID: 7.6
# Paragraph node created with ContextID: 7.6.4, linked to parent Paragraph ContextID: 7.6
# Paragraph node created with ContextID: 7.6.5, linked to parent Paragraph ContextID: 7.6
# Paragraph node created with ContextID: 7.7, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.7.1, linked to parent Paragraph ContextID: 7.7
# Paragraph node created with ContextID: 7.7.2, linked to parent Paragraph ContextID: 7.7
# Paragraph node created with ContextID: 7.7.3, linked to parent Paragraph ContextID: 7.7
# Paragraph node created with ContextID: 7.7.4, linked to parent Paragraph ContextID: 7.7
# Paragraph node created with ContextID: 7.8, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.8.1, linked to parent Paragraph ContextID: 7.8
# Paragraph node created with ContextID: 7.8.2.(a), linked to parent Paragraph ContextID: 7.8.2
# Paragraph node created with ContextID: 7.8.2.(b), linked to parent Paragraph ContextID: 7.8.2
# Paragraph node created with ContextID: 7.8.3, linked to parent Paragraph ContextID: 7.8
# Paragraph node created with ContextID: 7.8.4, linked to parent Paragraph ContextID: 7.8
# Paragraph node created with ContextID: 7.9, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.9.1, linked to parent Paragraph ContextID: 7.9
# Paragraph node created with ContextID: 7.9.2, linked to parent Paragraph ContextID: 7.9
# Paragraph node created with ContextID: 7.9.3, linked to parent Paragraph ContextID: 7.9
# Paragraph node created with ContextID: 7.9.3.(a), linked to parent Paragraph ContextID: 7.9.3
# Paragraph node created with ContextID: 7.9.3.(b), linked to parent Paragraph ContextID: 7.9.3
# Paragraph node created with ContextID: 7.9.3.(c), linked to parent Paragraph ContextID: 7.9.3
# Paragraph node created with ContextID: 7.10, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.10.1, linked to parent Paragraph ContextID: 7.10
# Paragraph node created with ContextID: 7.10.1.(a), linked to parent Paragraph ContextID: 7.10.1
# Paragraph node created with ContextID: 7.10.1.(b), linked to parent Paragraph ContextID: 7.10.1
# Paragraph node created with ContextID: 7.10.2, linked to parent Paragraph ContextID: 7.10
# Paragraph node created with ContextID: 7.10.3, linked to parent Paragraph ContextID: 7.10
# Paragraph node created with ContextID: 7.10.4, linked to parent Paragraph ContextID: 7.10
# Paragraph node created with ContextID: 7.10.5, linked to parent Paragraph ContextID: 7.10
# Paragraph node created with ContextID: 7.11, linked to parent Paragraph ContextID: 7
# Paragraph node created with ContextID: 7.11.1, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.2, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.2.(a), linked to parent Paragraph ContextID: 7.11.2
# Paragraph node created with ContextID: 7.11.2.(b), linked to parent Paragraph ContextID: 7.11.2
# Paragraph node created with ContextID: 7.11.3, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.4, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.5, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.6, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.7, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.8, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.9, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.10, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.11, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.12, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.13, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.14, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.15, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 7.11.16, linked to parent Paragraph ContextID: 7.11
# Paragraph node created with ContextID: 8, linked directly to Document
# Paragraph node created with ContextID: 8.1, linked to parent Paragraph ContextID: 8
# Paragraph node created with ContextID: 8.1.1, linked to parent Paragraph ContextID: 8.1
# Paragraph node created with ContextID: 8.2, linked to parent Paragraph ContextID: 8
# Paragraph node created with ContextID: 8.2.1, linked to parent Paragraph ContextID: 8.2
# Paragraph node created with ContextID: 8.2.1.Guidance, linked to parent Paragraph ContextID: 8.2.1
# Paragraph node created with ContextID: 8.2.1.Guidance.1, linked to parent Paragraph ContextID: 8.2.1.Guidance
# Paragraph node created with ContextID: 8.2.1.Guidance.2, linked to parent Paragraph ContextID: 8.2.1.Guidance
# Paragraph node created with ContextID: 8.2.2, linked to parent Paragraph ContextID: 8.2
# Paragraph node created with ContextID: 8.2.2.Guidance, linked to parent Paragraph ContextID: 8.2.2
# Paragraph node created with ContextID: 8.2.2.Guidance.1, linked to parent Paragraph ContextID: 8.2.2.Guidance
# Paragraph node created with ContextID: 8.3, linked to parent Paragraph ContextID: 8
# Paragraph node created with ContextID: 8.4, linked to parent Paragraph ContextID: 8
# Paragraph node created with ContextID: 8.4.1, linked to parent Paragraph ContextID: 8.4
# Paragraph node created with ContextID: 8.4.2, linked to parent Paragraph ContextID: 8.4
# Paragraph node created with ContextID: 8.4.3, linked to parent Paragraph ContextID: 8.4
# Paragraph node created with ContextID: 8.4.4, linked to parent Paragraph ContextID: 8.4
# Paragraph node created with ContextID: 8.4.5, linked to parent Paragraph ContextID: 8.4
# Paragraph node created with ContextID: 8.5, linked to parent Paragraph ContextID: 8
# Paragraph node created with ContextID: 8.5.1, linked to parent Paragraph ContextID: 8.5
# Paragraph node created with ContextID: 8.5.2, linked to parent Paragraph ContextID: 8.5
# Paragraph node created with ContextID: 8.6, linked to parent Paragraph ContextID: 8
# Paragraph node created with ContextID: 8.6.1, linked to parent Paragraph ContextID: 8.6
# Paragraph node created with ContextID: 8.6.2, linked to parent Paragraph ContextID: 8.6
# Paragraph node created with ContextID: 8.6.3, linked to parent Paragraph ContextID: 8.6
# Paragraph node created with ContextID: 8.6.4, linked to parent Paragraph ContextID: 8.6
# Paragraph node created with ContextID: 8.6.5, linked to parent Paragraph ContextID: 8.6
# Paragraph node created with ContextID: 8.6.6, linked to parent Paragraph ContextID: 8.6
# Paragraph node created with ContextID: 8.6.7, linked to parent Paragraph ContextID: 8.6
# Paragraph node created with ContextID: 8.6.8, linked to parent Paragraph ContextID: 8.6
# Paragraph node created with ContextID: 9, linked directly to Document
# Paragraph node created with ContextID: 9.1, linked to parent Paragraph ContextID: 9
# Paragraph node created with ContextID: 9.1.1, linked to parent Paragraph ContextID: 9.1
# Paragraph node created with ContextID: 9.1.2, linked to parent Paragraph ContextID: 9.1
# Paragraph node created with ContextID: 9.1.3, linked to parent Paragraph ContextID: 9.1
# Paragraph node created with ContextID: 9.1.3.Guidance, linked to parent Paragraph ContextID: 9.1.3
# Paragraph node created with ContextID: 9.1.3.Guidance.1, linked to parent Paragraph ContextID: 9.1.3.Guidance
# Paragraph node created with ContextID: 9.1.3.Guidance.2, linked to parent Paragraph ContextID: 9.1.3.Guidance
# Paragraph node created with ContextID: 9.2, linked to parent Paragraph ContextID: 9
# Paragraph node created with ContextID: 9.2.1, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.2.2, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.2.3, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.2.4, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.2.5, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.2.6, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.2.7, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.2.8, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.2.9, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.2.10, linked to parent Paragraph ContextID: 9.2
# Paragraph node created with ContextID: 9.3, linked to parent Paragraph ContextID: 9
# Paragraph node created with ContextID: 9.3.1, linked to parent Paragraph ContextID: 9.3
# Paragraph node created with ContextID: 9.3.2, linked to parent Paragraph ContextID: 9.3
# Paragraph node created with ContextID: 9.4, linked to parent Paragraph ContextID: 9
# Paragraph node created with ContextID: 9.4.1, linked to parent Paragraph ContextID: 9.4
# Paragraph node created with ContextID: 9.4.2, linked to parent Paragraph ContextID: 9.4
# Paragraph node created with ContextID: 9.4.3, linked to parent Paragraph ContextID: 9.4
# Paragraph node created with ContextID: 9.5, linked to parent Paragraph ContextID: 9
# Paragraph node created with ContextID: 9.5.1, linked to parent Paragraph ContextID: 9.5
# Paragraph node created with ContextID: 9.5.2, linked to parent Paragraph ContextID: 9.5
# Paragraph node created with ContextID: 9.5.3, linked to parent Paragraph ContextID: 9.5
# Paragraph node created with ContextID: 9.5.4, linked to parent Paragraph ContextID: 9.5
# Paragraph node created with ContextID: 9.5.5, linked to parent Paragraph ContextID: 9.5
# Paragraph node created with ContextID: 9.5.6, linked to parent Paragraph ContextID: 9.5
# Paragraph node created with ContextID: 9.5.7, linked to parent Paragraph ContextID: 9.5
# Paragraph node created with ContextID: 9.5.7.Guidance, linked to parent Paragraph ContextID: 9.5.7
# Paragraph node created with ContextID: 9.5.7.Guidance.1, linked to parent Paragraph ContextID: 9.5.7.Guidance
# Paragraph node created with ContextID: 9.6, linked to parent Paragraph ContextID: 9
# Paragraph node created with ContextID: 9.6.1, linked to parent Paragraph ContextID: 9.6
# Paragraph node created with ContextID: 9.6.2, linked to parent Paragraph ContextID: 9.6
# Paragraph node created with ContextID: 9.6.3, linked to parent Paragraph ContextID: 9.6
# Paragraph node created with ContextID: 9.6.4, linked to parent Paragraph ContextID: 9.6
# Paragraph node created with ContextID: 9.6.5, linked to parent Paragraph ContextID: 9.6
# Paragraph node created with ContextID: 9.7, linked to parent Paragraph ContextID: 9
# Paragraph node created with ContextID: 9.7.1, linked to parent Paragraph ContextID: 9.7
# Paragraph node created with ContextID: 9.7.2, linked to parent Paragraph ContextID: 9.7
# ...
# Paragraph node created with ContextID: 20.7.3, linked to parent Paragraph ContextID: 20.7
# Paragraph node created with ContextID: 20.7.4, linked to parent Paragraph ContextID: 20.7
# Paragraph node created with ContextID: 20.8, linked to parent Paragraph ContextID: 20
# Paragraph node created with ContextID: 20.8.1.(1), linked to parent Paragraph ContextID: 20.8.1
# Paragraph node created with ContextID: 20.8.1.(2), linked to parent Paragraph ContextID: 20.8.1
# Paragraph node created with ContextID: 20.8.1.(3), linked to parent Paragraph ContextID: 20.8.1
# Paragraph node created with ContextID: 20.8.2.(1), linked to parent Paragraph ContextID: 20.8.2
# Paragraph node created with ContextID: 20.8.2.(2), linked to parent Paragraph ContextID: 20.8.2
# Paragraph node created with ContextID: 20.8.2.(3), linked to parent Paragraph ContextID: 20.8.2
# Paragraph node created with ContextID: 20.9, linked to parent Paragraph ContextID: 20
# Paragraph node created with ContextID: 20.9.1, linked to parent Paragraph ContextID: 20.9
# Paragraph node created with ContextID: 20.9.2, linked to parent Paragraph ContextID: 20.9
# Paragraph node created with ContextID: 20.9.3, linked to parent Paragraph ContextID: 20.9
# Paragraph node created with ContextID: 20.10, linked to parent Paragraph ContextID: 20
# Paragraph node created with ContextID: 20.10.1, linked to parent Paragraph ContextID: 20.10
# Paragraph node created with ContextID: 20.10.2, linked to parent Paragraph ContextID: 20.10
# Paragraph node created with ContextID: 20.10.3, linked to parent Paragraph ContextID: 20.10
# Paragraph node created with ContextID: 20.10.4, linked to parent Paragraph ContextID: 20.10
# Paragraph node created with ContextID: 20.11, linked to parent Paragraph ContextID: 20
# Paragraph node created with ContextID: 20.11.1, linked to parent Paragraph ContextID: 20.11
# Paragraph node created with ContextID: 20.11.2, linked to parent Paragraph ContextID: 20.11
# Paragraph node created with ContextID: 20.11.3, linked to parent Paragraph ContextID: 20.11
# Paragraph node created with ContextID: 20.12, linked to parent Paragraph ContextID: 20
# Paragraph node created with ContextID: 20.12.1, linked to parent Paragraph ContextID: 20.12
# Paragraph node created with ContextID: 20.12.2, linked to parent Paragraph ContextID: 20.12
# Paragraph node created with ContextID: 20.12.3, linked to parent Paragraph ContextID: 20.12
# Paragraph node created with ContextID: 20.12.4, linked to parent Paragraph ContextID: 20.12
# Paragraph node created with ContextID: 20.12.5, linked to parent Paragraph ContextID: 20.12
# Paragraph node created with ContextID: 20.12.6, linked to parent Paragraph ContextID: 20.12
# Paragraph node created with ContextID: 20.13, linked to parent Paragraph ContextID: 20
# Paragraph node created with ContextID: 20.13.1, linked to parent Paragraph ContextID: 20.13
# Paragraph node created with ContextID: 20.13.2, linked to parent Paragraph ContextID: 20.13
# Paragraph node created with ContextID: 20.13.3, linked to parent Paragraph ContextID: 20.13
# Paragraph node created with ContextID: 20.13.4, linked to parent Paragraph ContextID: 20.13
# Paragraph node created with ContextID: 20.14, linked to parent Paragraph ContextID: 20
# Paragraph node created with ContextID: 20.14.1.(1), linked to parent Paragraph ContextID: 20.14.1
# Paragraph node created with ContextID: 20.14.1.(2), linked to parent Paragraph ContextID: 20.14.1
# Paragraph node created with ContextID: 20.14.1.(3), linked to parent Paragraph ContextID: 20.14.1
# Paragraph node created with ContextID: 20.14.1.(4), linked to parent Paragraph ContextID: 20.14.1
# Paragraph node created with ContextID: 20.14.1.Guidance, linked to parent Paragraph ContextID: 20.14.1
# Paragraph node created with ContextID: 20.14.1.Guidance.1, linked to parent Paragraph ContextID: 20.14.1.Guidance
# Paragraph node created with ContextID: 20.14.2.(1), linked to parent Paragraph ContextID: 20.14.2
# Paragraph node created with ContextID: 20.14.2.(2), linked to parent Paragraph ContextID: 20.14.2
# Paragraph node created with ContextID: 20.14.2.(3), linked to parent Paragraph ContextID: 20.14.2
# Paragraph node created with ContextID: 20.14.2.Guidance, linked to parent Paragraph ContextID: 20.14.2
# Paragraph node created with ContextID: 20.14.2.Guidance.1, linked to parent Paragraph ContextID: 20.14.2.Guidance
# Paragraph node created with ContextID: 20.14.2.Guidance.2, linked to parent Paragraph ContextID: 20.14.2.Guidance
# Paragraph node created with ContextID: 20.14.3.(1), linked to parent Paragraph ContextID: 20.14.3
# Paragraph node created with ContextID: 20.14.3.(2), linked to parent Paragraph ContextID: 20.14.3
# Paragraph node created with ContextID: 20.14.3.(3), linked to parent Paragraph ContextID: 20.14.3
# Paragraph node created with ContextID: 20.14.3.(4), linked to parent Paragraph ContextID: 20.14.3
# Paragraph node created with ContextID: 20.14.3.(5), linked to parent Paragraph ContextID: 20.14.3
# Paragraph node created with ContextID: 20.14.3.Guidance, linked to parent Paragraph ContextID: 20.14.3
# Paragraph node created with ContextID: 20.14.3.Guidance.1, linked to parent Paragraph ContextID: 20.14.3.Guidance
# Paragraph node created with ContextID: 20.14.3.Guidance.2, linked to parent Paragraph ContextID: 20.14.3.Guidance
# Paragraph node created with ContextID: 20.14.3.Guidance.3, linked to parent Paragraph ContextID: 20.14.3.Guidance
# Paragraph node created with ContextID: 20.14.4.(1), linked to parent Paragraph ContextID: 20.14.4
# Paragraph node created with ContextID: 20.14.4.(1).Guidance, linked to parent Paragraph ContextID: 20.14.4.(1)
# Paragraph node created with ContextID: 20.14.4.(1).Guidance.1, linked to parent Paragraph ContextID: 20.14.4.(1).Guidance
# Paragraph node created with ContextID: 20.15, linked to parent Paragraph ContextID: 20
# Paragraph node created with ContextID: 20.15.1, linked to parent Paragraph ContextID: 20.15
# Paragraph node created with ContextID: 21, linked directly to Document
# Paragraph node created with ContextID: 21.1, linked to parent Paragraph ContextID: 21
# Paragraph node created with ContextID: 21.1.1, linked to parent Paragraph ContextID: 21.1
# Paragraph node created with ContextID: 21.1.2, linked to parent Paragraph ContextID: 21.1
# Paragraph node created with ContextID: 21.2, linked to parent Paragraph ContextID: 21
# Paragraph node created with ContextID: 21.2.1, linked to parent Paragraph ContextID: 21.2
# Paragraph node created with ContextID: 21.3, linked to parent Paragraph ContextID: 21
# Paragraph node created with ContextID: 21.3.1, linked to parent Paragraph ContextID: 21.3
# Paragraph node created with ContextID: 21.3.2, linked to parent Paragraph ContextID: 21.3
# Paragraph node created with ContextID: 21.3.3, linked to parent Paragraph ContextID: 21.3
# Paragraph node created with ContextID: 21.3.4, linked to parent Paragraph ContextID: 21.3
# Paragraph node created with ContextID: 21.3.5, linked to parent Paragraph ContextID: 21.3
# Paragraph node created with ContextID: 21.3.5.Guidance, linked to parent Paragraph ContextID: 21.3.5
# Paragraph node created with ContextID: 21.3.5.Guidance.1, linked to parent Paragraph ContextID: 21.3.5.Guidance
# Paragraph node created with ContextID: 21.3.5.Guidance.2, linked to parent Paragraph ContextID: 21.3.5.Guidance
# Paragraph node created with ContextID: 21.3.6, linked to parent Paragraph ContextID: 21.3
# Paragraph node created with ContextID: 21.4, linked to parent Paragraph ContextID: 21
# Paragraph node created with ContextID: 21.4.1, linked to parent Paragraph ContextID: 21.4
# Paragraph node created with ContextID: 21.4.2, linked to parent Paragraph ContextID: 21.4
# Paragraph node created with ContextID: 21.4.3, linked to parent Paragraph ContextID: 21.4
# Paragraph node created with ContextID: 21.4.4, linked to parent Paragraph ContextID: 21.4
# Paragraph node created with ContextID: 22, linked directly to Document
# Paragraph node created with ContextID: 22.1, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.1.1, linked to parent Paragraph ContextID: 22.1
# Paragraph node created with ContextID: 22.1.2, linked to parent Paragraph ContextID: 22.1
# Paragraph node created with ContextID: 22.2, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.2.1, linked to parent Paragraph ContextID: 22.2
# Paragraph node created with ContextID: 22.2.2, linked to parent Paragraph ContextID: 22.2
# Paragraph node created with ContextID: 22.2.3, linked to parent Paragraph ContextID: 22.2
# Paragraph node created with ContextID: 22.3, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.3.1, linked to parent Paragraph ContextID: 22.3
# Paragraph node created with ContextID: 22.3.2, linked to parent Paragraph ContextID: 22.3
# Paragraph node created with ContextID: 22.4, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.4.1, linked to parent Paragraph ContextID: 22.4
# Paragraph node created with ContextID: 22.4.2, linked to parent Paragraph ContextID: 22.4
# Paragraph node created with ContextID: 22.4.3, linked to parent Paragraph ContextID: 22.4
# Paragraph node created with ContextID: 22.4.4, linked to parent Paragraph ContextID: 22.4
# Paragraph node created with ContextID: 22.4.5, linked to parent Paragraph ContextID: 22.4
# Paragraph node created with ContextID: 22.4.6, linked to parent Paragraph ContextID: 22.4
# Paragraph node created with ContextID: 22.5, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.5.1, linked to parent Paragraph ContextID: 22.5
# Paragraph node created with ContextID: 22.6, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.6.1, linked to parent Paragraph ContextID: 22.6
# Paragraph node created with ContextID: 22.7, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.7.1, linked to parent Paragraph ContextID: 22.7
# Paragraph node created with ContextID: 22.7.2, linked to parent Paragraph ContextID: 22.7
# Paragraph node created with ContextID: 22.7.3, linked to parent Paragraph ContextID: 22.7
# Paragraph node created with ContextID: 22.7.4, linked to parent Paragraph ContextID: 22.7
# Paragraph node created with ContextID: 22.7.5, linked to parent Paragraph ContextID: 22.7
# Paragraph node created with ContextID: 22.7.6, linked to parent Paragraph ContextID: 22.7
# Paragraph node created with ContextID: 22.8, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.8.1, linked to parent Paragraph ContextID: 22.8
# Paragraph node created with ContextID: 22.8.2, linked to parent Paragraph ContextID: 22.8
# Paragraph node created with ContextID: 22.8.3, linked to parent Paragraph ContextID: 22.8
# Paragraph node created with ContextID: 22.9, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.9.1, linked to parent Paragraph ContextID: 22.9
# Paragraph node created with ContextID: 22.9.2, linked to parent Paragraph ContextID: 22.9
# Paragraph node created with ContextID: 22.9.3, linked to parent Paragraph ContextID: 22.9
# Paragraph node created with ContextID: 22.10, linked to parent Paragraph ContextID: 22
# Paragraph node created with ContextID: 22.10.1, linked to parent Paragraph ContextID: 22.10
# Paragraph node created with ContextID: 22.10.1.Guidance, linked to parent Paragraph ContextID: 22.10.1
# Paragraph node created with ContextID: 22.10.1.Guidance.1, linked to parent Paragraph ContextID: 22.10.1.Guidance
# Paragraph node created with ContextID: 23, linked directly to Document
# Paragraph node created with ContextID: 23.1, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.2, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.3, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.4, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.4.1, linked to parent Paragraph ContextID: 23.4
# Paragraph node created with ContextID: 23.4.2, linked to parent Paragraph ContextID: 23.4
# Paragraph node created with ContextID: 23.4.3, linked to parent Paragraph ContextID: 23.4
# Paragraph node created with ContextID: 23.4.4, linked to parent Paragraph ContextID: 23.4
# Paragraph node created with ContextID: 23.4.5, linked to parent Paragraph ContextID: 23.4
# Paragraph node created with ContextID: 23.4.6, linked to parent Paragraph ContextID: 23.4
# Paragraph node created with ContextID: 23.4.7, linked to parent Paragraph ContextID: 23.4
# Paragraph node created with ContextID: 23.4.8, linked to parent Paragraph ContextID: 23.4
# Paragraph node created with ContextID: 23.4.8.Guidance, linked to parent Paragraph ContextID: 23.4.8
# Paragraph node created with ContextID: 23.4.8.Guidance.1, linked to parent Paragraph ContextID: 23.4.8.Guidance
# Paragraph node created with ContextID: 23.4.8.Guidance.2, linked to parent Paragraph ContextID: 23.4.8.Guidance
# Paragraph node created with ContextID: 23.5, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.5.1, linked to parent Paragraph ContextID: 23.5
# Paragraph node created with ContextID: 23.5.1.Guidance, linked to parent Paragraph ContextID: 23.5.1
# Paragraph node created with ContextID: 23.5.1.Guidance.1, linked to parent Paragraph ContextID: 23.5.1.Guidance
# Paragraph node created with ContextID: 23.5.1.Guidance.2, linked to parent Paragraph ContextID: 23.5.1.Guidance
# Paragraph node created with ContextID: 23.5.2, linked to parent Paragraph ContextID: 23.5
# Paragraph node created with ContextID: 23.6, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.6.Guidance, linked to parent Paragraph ContextID: 23.6
# Paragraph node created with ContextID: 23.6.Guidance.1, linked to parent Paragraph ContextID: 23.6.Guidance
# Paragraph node created with ContextID: 23.6.Guidance.2, linked to parent Paragraph ContextID: 23.6.Guidance
# Paragraph node created with ContextID: 23.7, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.7.1, linked to parent Paragraph ContextID: 23.7
# Paragraph node created with ContextID: 23.7.2, linked to parent Paragraph ContextID: 23.7
# Paragraph node created with ContextID: 23.7.2.Guidance, linked to parent Paragraph ContextID: 23.7.2
# Paragraph node created with ContextID: 23.7.2.Guidance.1, linked to parent Paragraph ContextID: 23.7.2.Guidance
# Paragraph node created with ContextID: 23.8, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.8.Guidance, linked to parent Paragraph ContextID: 23.8
# Paragraph node created with ContextID: 23.8.Guidance.1, linked to parent Paragraph ContextID: 23.8.Guidance
# Paragraph node created with ContextID: 23.8.Guidance.2, linked to parent Paragraph ContextID: 23.8.Guidance
# Paragraph node created with ContextID: 23.9, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.10, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.10.1, linked to parent Paragraph ContextID: 23.10
# Paragraph node created with ContextID: 23.10.2, linked to parent Paragraph ContextID: 23.10
# Paragraph node created with ContextID: 23.10.3, linked to parent Paragraph ContextID: 23.10
# Paragraph node created with ContextID: 23.10.3.Guidance, linked to parent Paragraph ContextID: 23.10.3
# Paragraph node created with ContextID: 23.10.3.Guidance.1, linked to parent Paragraph ContextID: 23.10.3.Guidance
# Paragraph node created with ContextID: 23.11, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.12, linked to parent Paragraph ContextID: 23
# Paragraph node created with ContextID: 23.12.1, linked to parent Paragraph ContextID: 23.12
# Paragraph node created with ContextID: 23.12.2, linked to parent Paragraph ContextID: 23.12
# Paragraph node created with ContextID: 23.12.3, linked to parent Paragraph ContextID: 23.12
# Connection to Neo4j closed.
