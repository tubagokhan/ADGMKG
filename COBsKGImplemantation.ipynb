# %%
import json
import string
import random
from neo4j import GraphDatabase

uri = "bolt://localhost:7687"
user = "neo4j"
password = "12345678"
json_file_path = r"C:\Users\Tuba.Gokhan\Desktop\KG\CoBs_Obligations_Named_Entities_Defined_Terms (1).json"

class Neo4jConnection:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))
        self.used_ids = set()
        print("Connected to Neo4j.")  

    def close(self):
        self.driver.close()
        print("Connection to Neo4j closed.") 
        
    def clear_database(self):
        with self.driver.session(database="documents") as session:
            session.run("MATCH (n) DETACH DELETE n")
            self.used_ids.clear()
            print("Previous data deleted from the database.")  

    def generate_unique_id(self, length=8):
        characters = string.ascii_letters + string.digits
        while True:
            unique_id = ''.join(random.choice(characters) for _ in range(length))
            if unique_id not in self.used_ids:
                self.used_ids.add(unique_id)
                #print(f"Generated unique ID: {unique_id}") 
                return unique_id

    def create_paragraphs_and_obligations(self, document_title, document_version, document_date, data):
        self.clear_database()
        print("Creating paragraphs and obligations...")  
        with self.driver.session(database="documents") as session:
            doc_id = self.generate_unique_id()
            print(f"Creating Document node with ID: {doc_id}")  
            session.run("CREATE (:Document {id: $id, title: $title, version: $version, date: $date})", 
                        id=doc_id, title=document_title, version=document_version, date=document_date)
            
            for item in data:
                if item['ContextID'].endswith('.'):
                    item['ContextID'] = item['ContextID'][:-1]
                # Create Paragraph node with a unique ID
                para_id = self.generate_unique_id()
                session.run("CREATE (p:Paragraph {id: $id, contextID: $contextID, text: $text}) RETURN p", 
                            id=para_id, contextID=item['ContextID'], text=item['Text'])
                
                # Determine parent ID (document or another paragraph)
                parent_context_id = '.'.join(item['ContextID'].split('.')[:-1])
                if parent_context_id:
                    # Link to parent paragraph
                    session.run("""
                    MATCH (parent:Paragraph {contextID: $parent_context_id}), (child:Paragraph {id: $para_id})
                    MERGE (parent)-[:CONTAINS]->(child)
                    """, parent_context_id=parent_context_id, para_id=para_id)
                    print(f"Paragraph node created with ContextID: {item['ContextID']}, linked to parent Paragraph ContextID: {parent_context_id}")
                else:
                    # Link directly to document
                    session.run("""
                    MATCH (doc:Document {id: $doc_id}), (para:Paragraph {id: $para_id})
                    MERGE (doc)-[:CONTAINS]->(para)
                    """, doc_id=doc_id, para_id=para_id)
                    print(f"Paragraph node created with ContextID: {item['ContextID']}, linked directly to Document")
                
                self.create_obligations(session, para_id, item.get('Obligations', []))
                self.create_named_entities(session, para_id, item.get('NamedEntities', []))
                self.create_defined_terms(session, para_id, item.get('DefinedTerms', []))

    def create_obligations(self, session, para_id, obligations):
        #print(f"Creating Obligations for Paragraph ID: {para_id}")  
        for obligation_text in obligations:
            obli_id = self.generate_unique_id()
            #print(f"Creating Obligation node with ID: {obli_id}")  
            heading, description = self.parse_obligation_text(obligation_text)
            session.run("""
                MATCH (p:Paragraph {id: $para_id})
                CREATE (o:Obligation {id: $obli_id, heading: $heading, description: $description})
                MERGE (p)-[:HAS_OBLIGATION]->(o)
                """, para_id=para_id, obli_id=obli_id, heading=heading, description=description)

    def parse_obligation_text(self, text):
        #print(f"Parsing Obligation text: {text}")  
        # Remove the last character if it is a double quote
        if text.endswith('"'):
            text = text[:-1]

        # Check if ':**' is in the text
        if '**' in text:
            # Find the start of the heading after ':**'
            temp = text.split('**')
            heading = temp[0].split('"')[1]
            description = temp[1]
        else:
            # Find the first occurrence of a double quote and use the rest of the text as the heading
            try:
                start_index = text.index(' \"') + 1  # Start after the first double quote
                heading = description =  text[start_index:]  # Assign the rest of the text to heading
            except ValueError:
                # Handle cases where the double quotes are not found or improperly formatted
                heading = "Invalid format or missing double quotes"
                description = ""

        # Remove leading double quotes from heading and description, if present
        if heading.endswith(':'):
            heading = heading[:-1]
        if heading.startswith('"'):
            heading = heading[1:]
        if description.startswith('"'):
            description = description[1:]
        if description.startswith(':'):
            description = description[1:]

        return heading, description

    def create_named_entities(self, session, para_id, named_entities):
        print(f"Creating Named Entities for Paragraph ID: {para_id}")  
        for entity in named_entities:
            entity_id = self.generate_unique_id()
            print(f"Creating Named Entity node with ID: {entity_id}")  
            session.run("""
                MATCH (p:Paragraph {id: $para_id})
                CREATE (e:NamedEntity {id: $entity_id, term: $term, description: $description})
                MERGE (p)-[:HAS_NAMED_ENTITY]->(e)
                """, para_id=para_id, entity_id=entity_id, term=entity['ContextID'], description=entity['Description'])

    def create_defined_terms(self, session, para_id, defined_terms):
        print(f"Creating Defined Terms for Paragraph ID: {para_id}")  # Print statement added
        for term in defined_terms:
            term_id = self.generate_unique_id()
            print(f"Creating Defined Term node with ID: {term_id}")  # Print statement added
            session.run("""
                MATCH (p:Paragraph {id: $para_id})
                CREATE (d:DefinedTerm {id: $term_id, term: $term, description: $description})
                MERGE (p)-[:HAS_DEFINED_TERM]->(d)
                """, para_id=para_id, term_id=term_id, term=term['ContextID'], description=term['Description'])

if __name__ == "__main__":
    conn = Neo4jConnection(uri, user, password)
    
    with open(json_file_path, 'r') as file:
        data = json.load(file)
    
    document_info = {
        "title": "Conduct of Business Rulebook (COBS)",
        "version": "VER15.150823",
        "date": "15/08/2023"
    }
    
    conn.create_paragraphs_and_obligations(document_info['title'], document_info['version'], document_info['date'], data)
    conn.close()
# Out:
# Connected to Neo4j.
# Previous data deleted from the database.
# Creating paragraphs and obligations...
# Creating Document node with ID: etQ9QTsh
# Paragraph node created with ContextID: 1, linked directly to Document
# Creating Named Entities for Paragraph ID: kIRMSKtO
# Creating Defined Terms for Paragraph ID: kIRMSKtO
# Paragraph node created with ContextID: 1.1, linked to parent Paragraph ContextID: 1
# Creating Named Entities for Paragraph ID: DMnls5k2
# Creating Defined Terms for Paragraph ID: DMnls5k2
# Creating Defined Term node with ID: jMXLoRVO
# Creating Defined Term node with ID: jkMqr9QV
# Creating Defined Term node with ID: MiWiYi9U
# Creating Defined Term node with ID: ciEbL6Ja
# Creating Defined Term node with ID: bBWv6GLI
# Creating Defined Term node with ID: BoQRStgI
# Paragraph node created with ContextID: 2, linked directly to Document
# Creating Named Entities for Paragraph ID: nhSt0T0P
# Creating Defined Terms for Paragraph ID: nhSt0T0P
# Paragraph node created with ContextID: 2.1, linked to parent Paragraph ContextID: 2
# Creating Named Entities for Paragraph ID: d7kfcICk
# Creating Defined Terms for Paragraph ID: d7kfcICk
# Paragraph node created with ContextID: 2.1.1, linked to parent Paragraph ContextID: 2.1
# Creating Named Entities for Paragraph ID: L3oZdWsh
# Creating Defined Terms for Paragraph ID: L3oZdWsh
# Creating Defined Term node with ID: v5tTGhLh
# Creating Defined Term node with ID: wusjL7kf
# Creating Defined Term node with ID: gNRlKnE9
# Paragraph node created with ContextID: 2.1.2, linked to parent Paragraph ContextID: 2.1
# Creating Named Entities for Paragraph ID: sFSuRkPc
# Creating Named Entity node with ID: IRDLr7yc
# Creating Defined Terms for Paragraph ID: sFSuRkPc
# Creating Defined Term node with ID: 9XfUa1ql
# Paragraph node created with ContextID: 2.1.3, linked to parent Paragraph ContextID: 2.1
# Creating Named Entities for Paragraph ID: PW2r1AHC
# Creating Named Entity node with ID: 7wr3bvyt
# Creating Named Entity node with ID: EEtSPODw
# Creating Defined Terms for Paragraph ID: PW2r1AHC
# Creating Defined Term node with ID: KnBezHbL
# Creating Defined Term node with ID: 9Gl5D4ne
# Creating Defined Term node with ID: 9VK0y7OF
# Creating Defined Term node with ID: 9W2nskHD
# Creating Defined Term node with ID: i4DFk43g
# Creating Defined Term node with ID: aVLw8ebb
# Creating Defined Term node with ID: 3xjvZKeN
# Creating Defined Term node with ID: jbE10r5w
# Creating Defined Term node with ID: gQMz2yNg
# Creating Defined Term node with ID: SW3OkXGX
# Creating Defined Term node with ID: pWQMwCT2
# Paragraph node created with ContextID: 2.1.3.Guidance, linked to parent Paragraph ContextID: 2.1.3
# Creating Named Entities for Paragraph ID: dHnSPSzg
# Creating Defined Terms for Paragraph ID: dHnSPSzg
# Paragraph node created with ContextID: 2.1.3.Guidance.1, linked to parent Paragraph ContextID: 2.1.3.Guidance
# Creating Named Entities for Paragraph ID: HR5qCB48
# Creating Named Entity node with ID: jmlo9uma
# Creating Named Entity node with ID: V5IMnkAb
# Creating Defined Terms for Paragraph ID: HR5qCB48
# Creating Defined Term node with ID: reL8CsD3
# Creating Defined Term node with ID: btcobtJA
# Creating Defined Term node with ID: hH9xNPWh
# Creating Defined Term node with ID: xM230VrH
# Creating Defined Term node with ID: 5j7I2BKM
# Creating Defined Term node with ID: o337lrTk
# Creating Defined Term node with ID: zRFjWZnW
# Creating Defined Term node with ID: rGxC2poJ
# Creating Defined Term node with ID: 9P2mhjw1
# Creating Defined Term node with ID: Ja2fGSDF
# Creating Defined Term node with ID: GJkp8JrC
# Paragraph node created with ContextID: 2.1.3.Guidance.2, linked to parent Paragraph ContextID: 2.1.3.Guidance
# Creating Named Entities for Paragraph ID: kaBpMIuS
# Creating Defined Terms for Paragraph ID: kaBpMIuS
# Creating Defined Term node with ID: nu5jjZzz
# Creating Defined Term node with ID: cAB7n1EE
# Creating Defined Term node with ID: M0MCRlmR
# Creating Defined Term node with ID: zFl5YSwa
# Creating Defined Term node with ID: f9vhz878
# Creating Defined Term node with ID: izLwIxMr
# Creating Defined Term node with ID: 76i1s1Wk
# Creating Defined Term node with ID: uKJBr5rX
# Paragraph node created with ContextID: 2.2, linked to parent Paragraph ContextID: 2
# Creating Named Entities for Paragraph ID: hgkHB6fw
# Creating Defined Terms for Paragraph ID: hgkHB6fw
# Paragraph node created with ContextID: 2.2.1, linked to parent Paragraph ContextID: 2.2
# Creating Named Entities for Paragraph ID: rzGAuPNq
# Creating Defined Terms for Paragraph ID: rzGAuPNq
# Creating Defined Term node with ID: 63SbVNMG
# Creating Defined Term node with ID: C8O1jZUr
# Creating Defined Term node with ID: WbuwGCfS
# Creating Defined Term node with ID: mXQPWdjO
# Creating Defined Term node with ID: Bh9FRywh
# Paragraph node created with ContextID: 2.2.2, linked to parent Paragraph ContextID: 2.2
# Creating Named Entities for Paragraph ID: Pt0Wbc0B
# Creating Defined Terms for Paragraph ID: Pt0Wbc0B
# Creating Defined Term node with ID: KxdfAhnm
# Creating Defined Term node with ID: H1KWhBIe
# Creating Defined Term node with ID: bWtgL9Yg
# Creating Defined Term node with ID: FsgPmg2s
# Creating Defined Term node with ID: dB0abheX
# Paragraph node created with ContextID: 2.2.2.Guidance, linked to parent Paragraph ContextID: 2.2.2
# Creating Named Entities for Paragraph ID: c4397tgC
# Creating Defined Terms for Paragraph ID: c4397tgC
# Paragraph node created with ContextID: 2.2.2.Guidance.1, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Creating Named Entities for Paragraph ID: p3nOEldJ
# Creating Defined Terms for Paragraph ID: p3nOEldJ
# Creating Defined Term node with ID: P2EXsYdh
# Creating Defined Term node with ID: GycJNZxL
# Creating Defined Term node with ID: dNjw193E
# Creating Defined Term node with ID: rI2B0PLE
# Creating Defined Term node with ID: StwBu02L
# Creating Defined Term node with ID: auxve1pZ
# Paragraph node created with ContextID: 2.2.2.Guidance.2, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Creating Named Entities for Paragraph ID: WGzQMTBy
# Creating Defined Terms for Paragraph ID: WGzQMTBy
# Creating Defined Term node with ID: uIfZWSON
# Creating Defined Term node with ID: nSJZ3ajL
# Creating Defined Term node with ID: tYax5310
# Creating Defined Term node with ID: g7FDPMbI
# Paragraph node created with ContextID: 2.2.2.Guidance.3, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Creating Named Entities for Paragraph ID: itfgowsX
# Creating Defined Terms for Paragraph ID: itfgowsX
# Creating Defined Term node with ID: 3R1Lp9xe
# Creating Defined Term node with ID: 6ywZwsit
# Creating Defined Term node with ID: 9wfHoYZZ
# Creating Defined Term node with ID: NjODA19F
# Creating Defined Term node with ID: DO7ejnAq
# Paragraph node created with ContextID: 2.2.2.Guidance.4, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Creating Named Entities for Paragraph ID: w74XgZii
# Creating Defined Terms for Paragraph ID: w74XgZii
# Creating Defined Term node with ID: yumDiAuL
# Creating Defined Term node with ID: fgXDYJly
# Creating Defined Term node with ID: ldlNmFRw
# Creating Defined Term node with ID: HRpaxXO8
# Creating Defined Term node with ID: BcXAZ9OL
# Creating Defined Term node with ID: Wvfmph5V
# Creating Defined Term node with ID: jhUgZDmP
# Creating Defined Term node with ID: d2muY0FE
# Creating Defined Term node with ID: qIhjGt16
# Creating Defined Term node with ID: KYRL950L
# Paragraph node created with ContextID: 2.2.2.Guidance.5, linked to parent Paragraph ContextID: 2.2.2.Guidance
# Creating Named Entities for Paragraph ID: 4s4cny1k
# Creating Defined Terms for Paragraph ID: 4s4cny1k
# Creating Defined Term node with ID: 6CmeP4Rw
# Creating Defined Term node with ID: VlRLyYEA
# Creating Defined Term node with ID: hVaWMGzP
# Creating Defined Term node with ID: tNBIri1u
# Paragraph node created with ContextID: 2.2.3, linked to parent Paragraph ContextID: 2.2
# Creating Named Entities for Paragraph ID: vJ4aW0Hc
# Creating Named Entity node with ID: yusbsNH4
# Creating Defined Terms for Paragraph ID: vJ4aW0Hc
# Creating Defined Term node with ID: afdzZlXw
# Creating Defined Term node with ID: 2W8uCuQx
# Creating Defined Term node with ID: Nv7rzTLk
# Creating Defined Term node with ID: QaJsLMe3
# Creating Defined Term node with ID: UieiTeow
# Creating Defined Term node with ID: cOM0llQd
# Creating Defined Term node with ID: UiJRRZ20
# Creating Defined Term node with ID: MNnAfg77
# Creating Defined Term node with ID: eWW1Ren2
# Paragraph node created with ContextID: 2.2.4, linked to parent Paragraph ContextID: 2.2
# Creating Named Entities for Paragraph ID: qe2Pv6hs
# Creating Defined Terms for Paragraph ID: qe2Pv6hs
# Creating Defined Term node with ID: Q8mis8YV
# Creating Defined Term node with ID: Tb7ptJo9
# Creating Defined Term node with ID: YIISSevF
# Creating Defined Term node with ID: DtwxNhIY
# Creating Defined Term node with ID: HUUlvq1Q
# Paragraph node created with ContextID: 2.3, linked to parent Paragraph ContextID: 2
# Creating Named Entities for Paragraph ID: J3T6mzLm
# Creating Defined Terms for Paragraph ID: J3T6mzLm
# Creating Defined Term node with ID: sqHdMtPf
# Creating Defined Term node with ID: hgyHbYI6
# Creating Defined Term node with ID: qqm5mhU3
# Creating Defined Term node with ID: l5ZLHB8c
# Creating Defined Term node with ID: LMgfZsjP
# Creating Defined Term node with ID: UtK0VftO
# Creating Defined Term node with ID: KQd6xyyb
# Paragraph node created with ContextID: 2.4, linked to parent Paragraph ContextID: 2
# Creating Named Entities for Paragraph ID: AQDwB0fP
# Creating Defined Terms for Paragraph ID: AQDwB0fP
# Creating Defined Term node with ID: WZvpgBh8
# Paragraph node created with ContextID: 2.4.1, linked to parent Paragraph ContextID: 2.4
# Creating Named Entities for Paragraph ID: QsQe6ogp
# Creating Defined Terms for Paragraph ID: QsQe6ogp
# Creating Defined Term node with ID: 39lGpltm
# Creating Defined Term node with ID: YLyusiu1
# Creating Defined Term node with ID: cQswR62T
# Paragraph node created with ContextID: 2.4.1.Guidance, linked to parent Paragraph ContextID: 2.4.1
# Creating Named Entities for Paragraph ID: 2LlE1mkZ
# Creating Defined Terms for Paragraph ID: 2LlE1mkZ
# Paragraph node created with ContextID: 2.4.1.Guidance.1, linked to parent Paragraph ContextID: 2.4.1.Guidance
# Creating Named Entities for Paragraph ID: WBIrgVcY
# Creating Defined Terms for Paragraph ID: WBIrgVcY
# Creating Defined Term node with ID: WJEmokFf
# Creating Defined Term node with ID: 6gI85NVg
# Paragraph node created with ContextID: 2.4.1.Guidance.2, linked to parent Paragraph ContextID: 2.4.1.Guidance
# Creating Named Entities for Paragraph ID: cTZGTpHx
# Creating Defined Terms for Paragraph ID: cTZGTpHx
# Creating Defined Term node with ID: VLHzIY1y
# Creating Defined Term node with ID: nj9l3Gmx
# Paragraph node created with ContextID: 2.4.2, linked to parent Paragraph ContextID: 2.4
# Creating Named Entities for Paragraph ID: JwMctIC8
# Creating Defined Terms for Paragraph ID: JwMctIC8
# Creating Defined Term node with ID: XhkLgolW
# Creating Defined Term node with ID: 6DKofLiS
# Paragraph node created with ContextID: 2.4.2.(a), linked to parent Paragraph ContextID: 2.4.2
# Creating Named Entities for Paragraph ID: Q73hH15r
# Creating Named Entity node with ID: 3A3G0DSm
# Creating Named Entity node with ID: nwE8ZXki
# Creating Named Entity node with ID: 7uY2N7jT
# Creating Named Entity node with ID: 1vDuMm4A
# Creating Named Entity node with ID: mP4EjWAP
# Creating Named Entity node with ID: F7Q1tFoo
# Creating Named Entity node with ID: nuVXUk1A
# Creating Named Entity node with ID: gFDNp26T
# Creating Named Entity node with ID: TphkXFAy
# Creating Named Entity node with ID: vVe0ptgO
# Creating Named Entity node with ID: 5MEqgoh6
# Creating Named Entity node with ID: Q4tju0vS
# Creating Named Entity node with ID: hSMlFNFL
# Creating Named Entity node with ID: zuFG52JD
# Creating Defined Terms for Paragraph ID: Q73hH15r
# Creating Defined Term node with ID: Db0LxEHk
# Creating Defined Term node with ID: aNDNcXYw
# Creating Defined Term node with ID: EQpCzg7Y
# Creating Defined Term node with ID: 6iAI6Xwp
# Creating Defined Term node with ID: DFg16IRg
# Creating Defined Term node with ID: NKHOxSdw
# Creating Defined Term node with ID: kVOANfpV
# Creating Defined Term node with ID: mwvVbeIb
# Creating Defined Term node with ID: pE2Y7a8L
# Creating Defined Term node with ID: FaygVhKm
# Creating Defined Term node with ID: QmS7krIx
# Creating Defined Term node with ID: 9ewp5sDR
# Creating Defined Term node with ID: LAor87S7
# Creating Defined Term node with ID: INHDS3rG
# Creating Defined Term node with ID: ciDVQBmE
# Creating Defined Term node with ID: SL4iXka4
# Creating Defined Term node with ID: PsslIpC8
# Creating Defined Term node with ID: nXFePLNJ
# Paragraph node created with ContextID: 2.4.2.(b), linked to parent Paragraph ContextID: 2.4.2
# Creating Named Entities for Paragraph ID: waJsmK8B
# Creating Defined Terms for Paragraph ID: waJsmK8B
# Creating Defined Term node with ID: xxS9P3gA
# Creating Defined Term node with ID: 3yGHso12
# Creating Defined Term node with ID: RmRaLGwC
# Creating Defined Term node with ID: XNEhZifu
# Paragraph node created with ContextID: 2.4.3, linked to parent Paragraph ContextID: 2.4
# Creating Named Entities for Paragraph ID: TpmE8E9q
# Creating Defined Terms for Paragraph ID: TpmE8E9q
# Paragraph node created with ContextID: 2.4.4, linked to parent Paragraph ContextID: 2.4
# Creating Named Entities for Paragraph ID: VY8FT2aU
# Creating Defined Terms for Paragraph ID: VY8FT2aU
# Creating Defined Term node with ID: SrxU5E8S
# Creating Defined Term node with ID: 3zv1W3bw
# Paragraph node created with ContextID: 2.4.4.Individuals, linked to parent Paragraph ContextID: 2.4.4
# Creating Named Entities for Paragraph ID: NGJbh9Gv
# Creating Defined Terms for Paragraph ID: NGJbh9Gv
# Paragraph node created with ContextID: 2.4.4.Individuals.(a), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Creating Named Entities for Paragraph ID: pLhJ2B5U
# Creating Named Entity node with ID: WlIGJeVA
# Creating Defined Terms for Paragraph ID: pLhJ2B5U
# Creating Defined Term node with ID: vAXyhdhS
# Creating Defined Term node with ID: bk082o6y
# Paragraph node created with ContextID: 2.4.4.Individuals.(b), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Creating Named Entities for Paragraph ID: Hua37pG7
# Creating Named Entity node with ID: pHPwkuUk
# Creating Named Entity node with ID: iHXQvIqI
# Creating Named Entity node with ID: enQzdsbL
# Creating Named Entity node with ID: OTQPlAiu
# Creating Named Entity node with ID: esc7pg5V
# Creating Defined Terms for Paragraph ID: Hua37pG7
# Creating Defined Term node with ID: wW5u7bFJ
# Creating Defined Term node with ID: yVNGV5I6
# Creating Defined Term node with ID: jwbPNyq5
# Creating Defined Term node with ID: JKvkciJn
# Creating Defined Term node with ID: BuPpRq2n
# Creating Defined Term node with ID: 1gILfH2b
# Creating Defined Term node with ID: LEjQ7nXB
# Creating Defined Term node with ID: ptcxacdq
# Creating Defined Term node with ID: VhNEAPqh
# Creating Defined Term node with ID: zXD4qEwh
# Creating Defined Term node with ID: jWbEZnhK
# Creating Defined Term node with ID: wDFBXVhY
# Creating Defined Term node with ID: gbj9S69i
# Creating Defined Term node with ID: H8VV5RKX
# Creating Defined Term node with ID: 7rMxMZM2
# Paragraph node created with ContextID: 2.4.4.Individuals.(c), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Creating Named Entities for Paragraph ID: Dd9AL4za
# Creating Defined Terms for Paragraph ID: Dd9AL4za
# Creating Defined Term node with ID: vDnYjKyP
# Creating Defined Term node with ID: 50Z6EyGv
# Creating Defined Term node with ID: VLhWyVdE
# Creating Defined Term node with ID: aCqJQX2r
# Creating Defined Term node with ID: ZInte3dJ
# Creating Defined Term node with ID: QBS5etXK
# Paragraph node created with ContextID: 2.4.4.Individuals.(d), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Creating Named Entities for Paragraph ID: xhr4hFkJ
# Creating Named Entity node with ID: 69DNYPB2
# Creating Named Entity node with ID: yTy6TPL1
# Creating Defined Terms for Paragraph ID: xhr4hFkJ
# Creating Defined Term node with ID: X4UPTjs0
# Creating Defined Term node with ID: pWlxHWDy
# Creating Defined Term node with ID: MC8vvUWR
# Creating Defined Term node with ID: CMThXuIH
# Creating Defined Term node with ID: gESjj4fh
# Paragraph node created with ContextID: 2.4.4.Individuals.(e), linked to parent Paragraph ContextID: 2.4.4.Individuals
# Creating Named Entities for Paragraph ID: ShCyq4zD
# Creating Named Entity node with ID: IDm6xy5Y
# Creating Named Entity node with ID: sOUJLX9v
# Creating Defined Terms for Paragraph ID: ShCyq4zD
# Creating Defined Term node with ID: GsCTkcVW
# Creating Defined Term node with ID: A26D0jVe
# Creating Defined Term node with ID: mtlen1lJ
# Paragraph node created with ContextID: 2.4.4.Individuals.Guidance, linked to parent Paragraph ContextID: 2.4.4.Individuals
# Creating Named Entities for Paragraph ID: cs7zCqBp
# Creating Defined Terms for Paragraph ID: cs7zCqBp
# Paragraph node created with ContextID: 2.4.4.Individuals.Guidance.1, linked to parent Paragraph ContextID: 2.4.4.Individuals.Guidance
# Creating Named Entities for Paragraph ID: b8hKThJC
# Creating Named Entity node with ID: t20FeHkm
# Creating Defined Terms for Paragraph ID: b8hKThJC
# Creating Defined Term node with ID: Z3U252KK
# Creating Defined Term node with ID: 8fa6JCxk
# Creating Defined Term node with ID: 8ww9uTiY
# Paragraph node created with ContextID: 2.4.4.Individuals.Guidance.2, linked to parent Paragraph ContextID: 2.4.4.Individuals.Guidance
# Creating Named Entities for Paragraph ID: it38OZcm
# Creating Named Entity node with ID: gvw9uoSV
# Creating Named Entity node with ID: g2BQGx3w
# Creating Named Entity node with ID: 1BYaFTVv
# Creating Defined Terms for Paragraph ID: it38OZcm
# Creating Defined Term node with ID: JkLeDt4S
# Creating Defined Term node with ID: jrI1lP8M
# Creating Defined Term node with ID: ifteEUvA
# Creating Defined Term node with ID: Y7b9epSR
# Creating Defined Term node with ID: i4cJUdv6
# Paragraph node created with ContextID: 2.4.4.Undertakings, linked to parent Paragraph ContextID: 2.4.4
# Creating Named Entities for Paragraph ID: GFBl8lrC
# Creating Named Entity node with ID: xGu0ASIw
# Creating Named Entity node with ID: rlZjRRWx
# Creating Named Entity node with ID: ejhmQasU
# Creating Named Entity node with ID: dua6tdya
# Creating Named Entity node with ID: 5FfuktXF
# Creating Named Entity node with ID: e2sZtgvA
# Creating Named Entity node with ID: IFJthdNl
# Creating Defined Terms for Paragraph ID: GFBl8lrC
# Creating Defined Term node with ID: GwxVMgyG
# Creating Defined Term node with ID: vKGAcLiI
# Creating Defined Term node with ID: n3jP02aZ
# Creating Defined Term node with ID: LjAybwmL
# Creating Defined Term node with ID: Lb0O51OJ
# Creating Defined Term node with ID: n7qMZzAJ
# Creating Defined Term node with ID: 767QXiLF
# Creating Defined Term node with ID: eN0MJtub
# Creating Defined Term node with ID: SX6aKq5A
# Creating Defined Term node with ID: v5C1kcbd
# Creating Defined Term node with ID: xIXkwzhS
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance, linked to parent Paragraph ContextID: 2.4.4.Undertakings
# Creating Named Entities for Paragraph ID: ALAJrwnI
# Creating Defined Terms for Paragraph ID: ALAJrwnI
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance.1, linked to parent Paragraph ContextID: 2.4.4.Undertakings.Guidance
# Creating Named Entities for Paragraph ID: 3xEKb8FO
# Creating Named Entity node with ID: 1Ioo31zS
# Creating Named Entity node with ID: N8qw00kF
# Creating Named Entity node with ID: I3PPYsFk
# Creating Named Entity node with ID: ucHAPmtp
# Creating Named Entity node with ID: 3LqPzGag
# Creating Named Entity node with ID: ugggLbBO
# Creating Defined Terms for Paragraph ID: 3xEKb8FO
# Creating Defined Term node with ID: waO084iR
# Creating Defined Term node with ID: npUpjsyq
# Creating Defined Term node with ID: bRHL1YjL
# Creating Defined Term node with ID: iXliec2x
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance.2, linked to parent Paragraph ContextID: 2.4.4.Undertakings.Guidance
# Creating Named Entities for Paragraph ID: SqHPRoBw
# Creating Named Entity node with ID: Gk6jgSq7
# Creating Named Entity node with ID: l0DqMuZz
# Creating Named Entity node with ID: jYMMbejt
# Creating Defined Terms for Paragraph ID: SqHPRoBw
# Creating Defined Term node with ID: pa3yxN7V
# Creating Defined Term node with ID: czR1hSXT
# Creating Defined Term node with ID: EV4qyskg
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance.3, linked to parent Paragraph ContextID: 2.4.4.Undertakings.Guidance
# Creating Named Entities for Paragraph ID: SWTMzpez
# Creating Defined Terms for Paragraph ID: SWTMzpez
# Creating Defined Term node with ID: VrSSdehf
# Creating Defined Term node with ID: pOiVObez
# Creating Defined Term node with ID: Viog59Rp
# Creating Defined Term node with ID: spLvd4ID
# Paragraph node created with ContextID: 2.4.4.Undertakings.Guidance.4, linked to parent Paragraph ContextID: 2.4.4.Undertakings.Guidance
# Creating Named Entities for Paragraph ID: Q6Mvp1xe
# Creating Defined Terms for Paragraph ID: Q6Mvp1xe
# Creating Defined Term node with ID: AhgJ5wUg
# Creating Defined Term node with ID: DvOMS1AI
# Creating Defined Term node with ID: 3xBpwdc7
# Creating Defined Term node with ID: wUFCppov
# Creating Defined Term node with ID: jz5NSzCQ
# Creating Defined Term node with ID: mnJKKb4O
# Creating Defined Term node with ID: KjH5ogNM
# Creating Defined Term node with ID: iQXFlYuK
# Creating Defined Term node with ID: Izs0ptKi
# Creating Defined Term node with ID: E6XbDZOI
# Creating Defined Term node with ID: 35xvEpZ3
# Creating Defined Term node with ID: MsmOREMk
# Paragraph node created with ContextID: 2.5, linked to parent Paragraph ContextID: 2
# Creating Named Entities for Paragraph ID: ovLYI97z
# Creating Defined Terms for Paragraph ID: ovLYI97z
# Paragraph node created with ContextID: 2.5.(a), linked to parent Paragraph ContextID: 2.5
# Creating Named Entities for Paragraph ID: iFe80HBH
# Creating Named Entity node with ID: ir6LBxq2
# Creating Defined Terms for Paragraph ID: iFe80HBH
# Creating Defined Term node with ID: tuAOMQCy
# Creating Defined Term node with ID: herISeHt
# Creating Defined Term node with ID: 8LzGDjrh
# Creating Defined Term node with ID: x462DBy0
# Creating Defined Term node with ID: E1OUP32q
# Creating Defined Term node with ID: 1PtTxs17
# Creating Defined Term node with ID: VUQbTryP
# Paragraph node created with ContextID: 2.5.(b), linked to parent Paragraph ContextID: 2.5
# Creating Named Entities for Paragraph ID: AoaCwUmC
# Creating Named Entity node with ID: xaguBP90
# Creating Defined Terms for Paragraph ID: AoaCwUmC
# Creating Defined Term node with ID: MZu8pYyH
# Creating Defined Term node with ID: Y0KwGOEo
# Creating Defined Term node with ID: 1GFK3S1R
# Creating Defined Term node with ID: re4Y48CJ
# Creating Defined Term node with ID: KQVyU03E
# Creating Defined Term node with ID: L8e39rB3
# Creating Defined Term node with ID: maAabpmm
# Creating Defined Term node with ID: 5mLbvRfd
# Creating Defined Term node with ID: LNzV7PP0
# Paragraph node created with ContextID: 2.5.Guidance In the case of a Market Counterparty which is a fund, trust or otherwise managed or held by a Person which qualifies as a “deemed” Professional Client, notification must be given to the Person which manages or holds the assets of the Market Counterparty, linked to parent Paragraph ContextID: 2.5
# Creating Named Entities for Paragraph ID: 6FYZTPb5
# Creating Defined Terms for Paragraph ID: 6FYZTPb5
# Paragraph node created with ContextID: 2.6, linked to parent Paragraph ContextID: 2
# Creating Named Entities for Paragraph ID: HlP6qtzm
# Creating Defined Terms for Paragraph ID: HlP6qtzm
# Paragraph node created with ContextID: 2.6.1, linked to parent Paragraph ContextID: 2.6
# Creating Named Entities for Paragraph ID: cwnJFlyF
# Creating Defined Terms for Paragraph ID: cwnJFlyF
# Creating Defined Term node with ID: K485Wrar
# Creating Defined Term node with ID: Vn4bnvKy
# Creating Defined Term node with ID: lToZJBtU
# Paragraph node created with ContextID: 2.6.1.(a), linked to parent Paragraph ContextID: 2.6.1
# Creating Named Entities for Paragraph ID: vrFrUuSJ
# Creating Named Entity node with ID: e84FI7Cl
# Creating Defined Terms for Paragraph ID: vrFrUuSJ
# Creating Defined Term node with ID: 5qtCZSWl
# Creating Defined Term node with ID: HIairJHX
# Creating Defined Term node with ID: ORHRsEhw
# Creating Defined Term node with ID: odogKlaV
# Creating Defined Term node with ID: m8Tex503
# Paragraph node created with ContextID: 2.6.1.(b), linked to parent Paragraph ContextID: 2.6.1
# Creating Named Entities for Paragraph ID: AOOmUh5h
# Creating Defined Terms for Paragraph ID: AOOmUh5h
# Creating Defined Term node with ID: 0a98jeCx
# Creating Defined Term node with ID: VtXFex1f
# Creating Defined Term node with ID: nxKNq6gF
# Creating Defined Term node with ID: 1wJOxXQM
# Creating Defined Term node with ID: IpJDZ3iS
# Paragraph node created with ContextID: 2.6.1.(c), linked to parent Paragraph ContextID: 2.6.1
# Creating Named Entities for Paragraph ID: zosLsRuz
# Creating Defined Terms for Paragraph ID: zosLsRuz
# Creating Defined Term node with ID: dWnFo9XD
# Creating Defined Term node with ID: NXE0sdPd
# Creating Defined Term node with ID: TxaADxVm
# Creating Defined Term node with ID: PyIlzyFT
# Creating Defined Term node with ID: Gyupq6dK
# Paragraph node created with ContextID: 2.6.1.(d), linked to parent Paragraph ContextID: 2.6.1
# Creating Named Entities for Paragraph ID: gr6PLkkC
# Creating Defined Terms for Paragraph ID: gr6PLkkC
# Creating Defined Term node with ID: NThgX3Cf
# Creating Defined Term node with ID: aLVTKO7T
# Creating Defined Term node with ID: 4XPWL4jH
# Creating Defined Term node with ID: JF5tPll6
# Creating Defined Term node with ID: JL8OElEy
# Paragraph node created with ContextID: 2.6.1.Guidance, linked to parent Paragraph ContextID: 2.6.1
# Creating Named Entities for Paragraph ID: CzvEo4uF
# Creating Defined Terms for Paragraph ID: CzvEo4uF
# Paragraph node created with ContextID: 2.6.1.Guidance.1, linked to parent Paragraph ContextID: 2.6.1.Guidance
# Creating Named Entities for Paragraph ID: rsyg6dOL
# Creating Defined Terms for Paragraph ID: rsyg6dOL
# Creating Defined Term node with ID: lq5aVLpZ
# Creating Defined Term node with ID: k3Wpc3fZ
# Creating Defined Term node with ID: cfpEmIu5
# Creating Defined Term node with ID: 4OlFnO2M
# Creating Defined Term node with ID: XLzaI0j8
# Creating Defined Term node with ID: WvOxXZf1
# Paragraph node created with ContextID: 2.6.1.Guidance.2, linked to parent Paragraph ContextID: 2.6.1.Guidance
# Creating Named Entities for Paragraph ID: uNHRkDtu
# Creating Named Entity node with ID: YTMEbUZZ
# Creating Defined Terms for Paragraph ID: uNHRkDtu
# Creating Defined Term node with ID: 72fmuCNn
# Creating Defined Term node with ID: iIuSKo5a
# Creating Defined Term node with ID: m5tYIwcp
# Creating Defined Term node with ID: 32RQx84E
# Creating Defined Term node with ID: tJgLSdGU
# Creating Defined Term node with ID: Gy5cF87T
# Paragraph node created with ContextID: 2.6.1.Guidance.3, linked to parent Paragraph ContextID: 2.6.1.Guidance
# Creating Named Entities for Paragraph ID: zaymRt9I
# Creating Named Entity node with ID: WYmqNzRH
# Creating Defined Terms for Paragraph ID: zaymRt9I
# Creating Defined Term node with ID: qzh7EfhI
# Creating Defined Term node with ID: ehENbDHG
# Creating Defined Term node with ID: neHkT1at
# Creating Defined Term node with ID: 1BigazZl
# Creating Defined Term node with ID: xOnsV93P
# Creating Defined Term node with ID: qNxqhRap
# Paragraph node created with ContextID: 2.6.2, linked to parent Paragraph ContextID: 2.6
# Creating Named Entities for Paragraph ID: BW6L6fsp
# Creating Defined Terms for Paragraph ID: BW6L6fsp
# Paragraph node created with ContextID: 2.6.2.(a), linked to parent Paragraph ContextID: 2.6.2
# Creating Named Entities for Paragraph ID: jnZ9ShCL
# Creating Named Entity node with ID: JKZXHO3o
# Creating Named Entity node with ID: mwThnPJn
# Creating Defined Terms for Paragraph ID: jnZ9ShCL
# Creating Defined Term node with ID: U2xcpJwR
# Creating Defined Term node with ID: WqAG0qKJ
# Creating Defined Term node with ID: jrv0ZdGo
# Creating Defined Term node with ID: DfgENcY3
# Creating Defined Term node with ID: CAs3Iszx
# Paragraph node created with ContextID: 2.6.2.(b), linked to parent Paragraph ContextID: 2.6.2
# Creating Named Entities for Paragraph ID: yEAtnntK
# Creating Defined Terms for Paragraph ID: yEAtnntK
# Creating Defined Term node with ID: OuRLZbEL
# Paragraph node created with ContextID: 2.6.3, linked to parent Paragraph ContextID: 2.6
# Creating Named Entities for Paragraph ID: mMX5cfWK
# Creating Defined Terms for Paragraph ID: mMX5cfWK
# Paragraph node created with ContextID: 2.6.3.(a), linked to parent Paragraph ContextID: 2.6.3
# Creating Named Entities for Paragraph ID: V2jWLIgZ
# Creating Named Entity node with ID: pOprWhKP
# Creating Named Entity node with ID: IBLTdjfB
# Creating Named Entity node with ID: DwWP4a0Y
# Creating Defined Terms for Paragraph ID: V2jWLIgZ
# Creating Defined Term node with ID: cWxA3zZc
# Creating Defined Term node with ID: N3OYCmAW
# Creating Defined Term node with ID: uB8Xf81K
# Creating Defined Term node with ID: bTHKQFHd
# Creating Defined Term node with ID: kDABNMyo
# Creating Defined Term node with ID: UzZ4iOEv
# Paragraph node created with ContextID: 2.6.3.(b), linked to parent Paragraph ContextID: 2.6.3
# Creating Named Entities for Paragraph ID: Fr8WgzLX
# Creating Defined Terms for Paragraph ID: Fr8WgzLX
# Creating Defined Term node with ID: yb7JKtxS
# Creating Defined Term node with ID: eZnU2lBf
# Creating Defined Term node with ID: pTnS9gdH
# Paragraph node created with ContextID: 2.6.3.Guidance, linked to parent Paragraph ContextID: 2.6.3
# Creating Named Entities for Paragraph ID: nKq35vpe
# Creating Defined Terms for Paragraph ID: nKq35vpe
# Paragraph node created with ContextID: 2.6.3.Guidance.1, linked to parent Paragraph ContextID: 2.6.3.Guidance
# Creating Named Entities for Paragraph ID: gxvqZnxF
# Creating Named Entity node with ID: HT3C2R6K
# Creating Named Entity node with ID: TxG5ZVwL
# Creating Named Entity node with ID: jAFX1Th9
# Creating Defined Terms for Paragraph ID: gxvqZnxF
# Creating Defined Term node with ID: aA8BbCgE
# Creating Defined Term node with ID: alwS28fu
# Creating Defined Term node with ID: PlGLN2lE
# Creating Defined Term node with ID: j8xmnVOl
# Creating Defined Term node with ID: bBdE7My2
# Paragraph node created with ContextID: 2.6.3.Guidance.2, linked to parent Paragraph ContextID: 2.6.3.Guidance
# Creating Named Entities for Paragraph ID: N4IN43J4
# Creating Named Entity node with ID: 3Kgc8rjx
# Creating Named Entity node with ID: yYuKvJYI
# Creating Named Entity node with ID: 6QsKx08r
# Creating Defined Terms for Paragraph ID: N4IN43J4
# Creating Defined Term node with ID: UFLQ8ie7
# Creating Defined Term node with ID: mHILgurZ
# Creating Defined Term node with ID: ysW0JPhM
# Creating Defined Term node with ID: mjgapn2h
# Paragraph node created with ContextID: 2.6.4, linked to parent Paragraph ContextID: 2.6
# Creating Named Entities for Paragraph ID: pOcngWQG
# Creating Named Entity node with ID: ixYDxt7v
# Creating Defined Terms for Paragraph ID: pOcngWQG
# Creating Defined Term node with ID: 5eA0gOmX
# Creating Defined Term node with ID: fjeeVb5Q
# Creating Defined Term node with ID: eXSGNioF
# Creating Defined Term node with ID: 8cehZxZc
# Creating Defined Term node with ID: m40XNiNv
# Creating Defined Term node with ID: xu4m4qc8
# Creating Defined Term node with ID: Uqm7svQ3
# Paragraph node created with ContextID: 2.6.4.Guidance, linked to parent Paragraph ContextID: 2.6.4
# Creating Named Entities for Paragraph ID: c0WlcPXI
# Creating Defined Terms for Paragraph ID: c0WlcPXI
# Paragraph node created with ContextID: 2.6.4.Guidance.1, linked to parent Paragraph ContextID: 2.6.4.Guidance
# Creating Named Entities for Paragraph ID: QoXa82FG
# Creating Named Entity node with ID: qBGnmPJ9
# Creating Defined Terms for Paragraph ID: QoXa82FG
# Creating Defined Term node with ID: SfuJeFJx
# Creating Defined Term node with ID: s3q13dV9
# Creating Defined Term node with ID: eA34ZunU
# Creating Defined Term node with ID: rHZIjKcq
# Creating Defined Term node with ID: A56ou2Mg
# Creating Defined Term node with ID: rCPATuwD
# Creating Defined Term node with ID: T6S1PFu3
# Paragraph node created with ContextID: 2.6.4.Guidance.2 In order to provide flexibility for Authorised Persons which are members of a Group to provide such services to their Clients in a manner that suits the Client's needs and the nature of the service, this Rule ‎2.6.4 sets out the overarching objectives that must be achieved, rather than any detailed requirements, linked to parent Paragraph ContextID: 2.6.4.Guidance.2 In order to provide flexibility for Authorised Persons which are members of a Group to provide such services to their Clients in a manner that suits the Client's needs and the nature of the service, this Rule ‎2.6
# Creating Named Entities for Paragraph ID: 584yyIA3
# Creating Defined Terms for Paragraph ID: 584yyIA3
# Paragraph node created with ContextID: 2.6.4.Guidance.3, linked to parent Paragraph ContextID: 2.6.4.Guidance
# Creating Named Entities for Paragraph ID: jAY4mmmH
# Creating Named Entity node with ID: j9xDyXVd
# Creating Named Entity node with ID: jpDwjjpD
# Creating Named Entity node with ID: t4j8qbPb
# Creating Named Entity node with ID: rfRBz0Fj
# Creating Defined Terms for Paragraph ID: jAY4mmmH
# Creating Defined Term node with ID: 8WFtc0M8
# Creating Defined Term node with ID: PmruYrtO
# Creating Defined Term node with ID: bUlQN8xZ
# Paragraph node created with ContextID: 2.6.4.Guidance.4, linked to parent Paragraph ContextID: 2.6.4.Guidance
# Creating Named Entities for Paragraph ID: GtNFMayD
# Creating Named Entity node with ID: w2FV5cD7
# Creating Defined Terms for Paragraph ID: GtNFMayD
# Creating Defined Term node with ID: eI5ip6Ml
# Creating Defined Term node with ID: J1hqVwGC
# Creating Defined Term node with ID: pwruunVL
# Creating Defined Term node with ID: UlWy9xJX
# Paragraph node created with ContextID: 2.7, linked to parent Paragraph ContextID: 2
# Creating Named Entities for Paragraph ID: Lk1S8Flb
# Creating Defined Terms for Paragraph ID: Lk1S8Flb
# Paragraph node created with ContextID: 2.7.1, linked to parent Paragraph ContextID: 2.7
# Creating Named Entities for Paragraph ID: v4S56bs1
# Creating Defined Terms for Paragraph ID: v4S56bs1
# Creating Defined Term node with ID: g6oh6lC9
# Creating Defined Term node with ID: VZHPeV96
# Creating Defined Term node with ID: CdoiUozK
# Creating Defined Term node with ID: PzDPEt5o
# Creating Defined Term node with ID: V6Z4JU97
# Paragraph node created with ContextID: 2.7.2, linked to parent Paragraph ContextID: 2.7
# Creating Named Entities for Paragraph ID: f6K166HA
# Creating Defined Terms for Paragraph ID: f6K166HA
# Creating Defined Term node with ID: hNVLREC0
# Creating Defined Term node with ID: tgRqQmB3
# Creating Defined Term node with ID: RGAeXnQX
# Paragraph node created with ContextID: 2.7.3, linked to parent Paragraph ContextID: 2.7
# Creating Named Entities for Paragraph ID: oo6xAZJI
# Creating Defined Terms for Paragraph ID: oo6xAZJI
# Creating Defined Term node with ID: dvXqUCQl
# Creating Defined Term node with ID: 3PH3ZtAj
# Creating Defined Term node with ID: 2Z1HYNWP
# Creating Defined Term node with ID: 1sFxXY8y
# Paragraph node created with ContextID: 2.7.4, linked to parent Paragraph ContextID: 2.7
# Creating Named Entities for Paragraph ID: YHmobb6K
# Creating Named Entity node with ID: RajRq0ra
# Creating Named Entity node with ID: 0VMPo1lC
# Creating Named Entity node with ID: qZ9omP4a
# Creating Defined Terms for Paragraph ID: YHmobb6K
# Creating Defined Term node with ID: Cd7TRwFX
# Creating Defined Term node with ID: 5S9suvrC
# Creating Defined Term node with ID: UT8tekHK
# Creating Defined Term node with ID: y0LkdjW8
# Creating Defined Term node with ID: QWXDv5Rp
# Creating Defined Term node with ID: brJdT4MT
# Paragraph node created with ContextID: 2.7.5, linked to parent Paragraph ContextID: 2.7
# Creating Named Entities for Paragraph ID: UjQ8jbHT
# Creating Defined Terms for Paragraph ID: UjQ8jbHT
# Creating Defined Term node with ID: tcv9cdPW
# Creating Defined Term node with ID: jsjliWUV
# Creating Defined Term node with ID: GUj58Zmf
# Paragraph node created with ContextID: 3.2, linked to parent Paragraph ContextID: 3
# Creating Named Entities for Paragraph ID: IoVZ6RAb
# Creating Defined Terms for Paragraph ID: IoVZ6RAb
# Creating Defined Term node with ID: jOjmeJoi
# Paragraph node created with ContextID: 3.2.1, linked to parent Paragraph ContextID: 3.2
# Creating Named Entities for Paragraph ID: knVPUCXP
# Creating Defined Terms for Paragraph ID: knVPUCXP
# Creating Defined Term node with ID: 2Xxv2npH
# Creating Defined Term node with ID: 2ILe2t33
# Creating Defined Term node with ID: CN2V1b4s
# Creating Defined Term node with ID: Ng66KuEh
# Creating Defined Term node with ID: 1JVe8dSA
# Paragraph node created with ContextID: 3.2.1.Guidance, linked to parent Paragraph ContextID: 3.2.1
# Creating Named Entities for Paragraph ID: bmPO4KGc
# Creating Defined Terms for Paragraph ID: bmPO4KGc
# Paragraph node created with ContextID: 3.2.1.Guidance.1, linked to parent Paragraph ContextID: 3.2.1.Guidance
# Creating Named Entities for Paragraph ID: bDN6S6sf
# Creating Defined Terms for Paragraph ID: bDN6S6sf
# Creating Defined Term node with ID: vJAXw39P
# Creating Defined Term node with ID: jt9l3K72
# Creating Defined Term node with ID: KVXAh3t9
# Paragraph node created with ContextID: 3.2.2, linked to parent Paragraph ContextID: 3.2
# Creating Named Entities for Paragraph ID: YzQUA9tx
# Creating Named Entity node with ID: 5CHdgFVb
# Creating Named Entity node with ID: qVJOsMBE
# Creating Defined Terms for Paragraph ID: YzQUA9tx
# Creating Defined Term node with ID: mXq5gz9s
# Creating Defined Term node with ID: 1z7yOHPT
# Creating Defined Term node with ID: xpNxTvS0
# Creating Defined Term node with ID: JFJMcVho
# Creating Defined Term node with ID: q4prUECr
# Paragraph node created with ContextID: 3.2.3, linked to parent Paragraph ContextID: 3.2
# Creating Named Entities for Paragraph ID: c24gRWuf
# Creating Defined Terms for Paragraph ID: c24gRWuf
# Creating Defined Term node with ID: NHfpXEEu
# Creating Defined Term node with ID: gysP3USS
# Creating Defined Term node with ID: uppJd4hY
# Creating Defined Term node with ID: GDtNpXh8
# Paragraph node created with ContextID: 3.2.4.(a), linked to parent Paragraph ContextID: 3.2.4
# Creating Named Entities for Paragraph ID: QwbpSL9C
# Creating Defined Terms for Paragraph ID: QwbpSL9C
# Creating Defined Term node with ID: srTZnVvR
# Creating Defined Term node with ID: sSEjt4Vj
# Creating Defined Term node with ID: m46hrtzP
# Creating Defined Term node with ID: b32xGCKb
# Creating Defined Term node with ID: CuWF7tQA
# Paragraph node created with ContextID: 3.2.4.(a).Guidance, linked to parent Paragraph ContextID: 3.2.4.(a)
# Creating Named Entities for Paragraph ID: GljSbHQJ
# Creating Defined Terms for Paragraph ID: GljSbHQJ
# Paragraph node created with ContextID: 3.2.4.(a).Guidance.1, linked to parent Paragraph ContextID: 3.2.4.(a).Guidance
# Creating Named Entities for Paragraph ID: 6h8MTd1s
# Creating Defined Terms for Paragraph ID: 6h8MTd1s
# Creating Defined Term node with ID: gLcIIKtn
# Paragraph node created with ContextID: 3.2.4.(b), linked to parent Paragraph ContextID: 3.2.4
# Creating Named Entities for Paragraph ID: JvV0Q828
# Creating Named Entity node with ID: 4VrMZ7XU
# Creating Named Entity node with ID: 7n80JnVY
# Creating Defined Terms for Paragraph ID: JvV0Q828
# Creating Defined Term node with ID: D2bJhZdI
# Creating Defined Term node with ID: tkQc9Wn9
# Creating Defined Term node with ID: s23248VK
# Creating Defined Term node with ID: kxu9r74o
# Creating Defined Term node with ID: KflhTYCx
# Creating Defined Term node with ID: hj6RMdfd
# Creating Defined Term node with ID: QQc5hPOX
# Creating Defined Term node with ID: C3a6qm5w
# Creating Defined Term node with ID: SDA66C4G
# Creating Defined Term node with ID: ZqJYRZ6Q
# Paragraph node created with ContextID: 3.2.4.(b).Guidance, linked to parent Paragraph ContextID: 3.2.4.(b)
# Creating Named Entities for Paragraph ID: mWWVQkSZ
# Creating Defined Terms for Paragraph ID: mWWVQkSZ
# Paragraph node created with ContextID: 3.2.4.(b).Guidance.1 Marketing Material includes any invitation or inducement to Engage in Investment Activity, linked to parent Paragraph ContextID: 3.2.4.(b).Guidance
# Creating Named Entities for Paragraph ID: UMmeLFK6
# Creating Defined Terms for Paragraph ID: UMmeLFK6
# Paragraph node created with ContextID: 3.2.5, linked to parent Paragraph ContextID: 3.2
# Creating Named Entities for Paragraph ID: b4vzwXSx
# Creating Defined Terms for Paragraph ID: b4vzwXSx
# Creating Defined Term node with ID: DwEkZkED
# Creating Defined Term node with ID: Hz1Qu6nQ
# Creating Defined Term node with ID: D1tFGUO1
# Creating Defined Term node with ID: Gv1fiKx3
# Creating Defined Term node with ID: 1WnFldM0
# Paragraph node created with ContextID: 3.2.6, linked to parent Paragraph ContextID: 3.2
# Creating Named Entities for Paragraph ID: wCMogmYN
# Creating Named Entity node with ID: HOgrKXWn
# Creating Named Entity node with ID: uK8KaLxP
# Creating Named Entity node with ID: g3ggWP8L
# Creating Defined Terms for Paragraph ID: wCMogmYN
# Creating Defined Term node with ID: ycdD4Ygn
# Creating Defined Term node with ID: X92XlWCG
# Creating Defined Term node with ID: FaF8n3XS
# Creating Defined Term node with ID: KvBubQtl
# Creating Defined Term node with ID: ocOAGG1L
# Creating Defined Term node with ID: 39XZZPAa
# Creating Defined Term node with ID: jgDRWttJ
# Paragraph node created with ContextID: 3.3, linked to parent Paragraph ContextID: 3
# Creating Named Entities for Paragraph ID: 1HJDFwKS
# Creating Named Entity node with ID: RogYQX5m
# Creating Defined Terms for Paragraph ID: 1HJDFwKS
# Creating Defined Term node with ID: 1bXu6XqP
# Creating Defined Term node with ID: YxX6SC13
# Paragraph node created with ContextID: 3.3.1, linked to parent Paragraph ContextID: 3.3
# Creating Named Entities for Paragraph ID: JpyYRIMC
# Creating Named Entity node with ID: LzLRS39r
# Creating Named Entity node with ID: ji6yCGKD
# Creating Named Entity node with ID: mKQ7644q
# Creating Named Entity node with ID: h4KPURqo
# Creating Defined Terms for Paragraph ID: JpyYRIMC
# Creating Defined Term node with ID: XThbCSv3
# Creating Defined Term node with ID: N2efdxxF
# Creating Defined Term node with ID: hkghzTZi
# Creating Defined Term node with ID: 6nWASHPT
# Creating Defined Term node with ID: rTNAsjje
# Creating Defined Term node with ID: fcRl1Bm5
# Creating Defined Term node with ID: 6kDRoSs8
# Creating Defined Term node with ID: A5A4tAMZ
# Creating Defined Term node with ID: PX0npwVi
# Creating Defined Term node with ID: e5ppLdvN
# Creating Defined Term node with ID: n2lwmXfx
# Creating Defined Term node with ID: 1lnVTR8g
# Creating Defined Term node with ID: 1wkE7HXx
# Creating Defined Term node with ID: hXlfW8Bn
# Creating Defined Term node with ID: PJwCystb
# Creating Defined Term node with ID: D0CC9m3C
# Creating Defined Term node with ID: lbJzQ43U
# Creating Defined Term node with ID: 6UrDAeoy
# Paragraph node created with ContextID: 3.3.2, linked to parent Paragraph ContextID: 3.3
# Creating Named Entities for Paragraph ID: x7sCwCVT
# Creating Defined Terms for Paragraph ID: x7sCwCVT
# Paragraph node created with ContextID: 3.3.2.(a), linked to parent Paragraph ContextID: 3.3.2
# Creating Named Entities for Paragraph ID: IPhE5RQJ
# Creating Named Entity node with ID: wgLca66a
# Creating Defined Terms for Paragraph ID: IPhE5RQJ
# Creating Defined Term node with ID: uppdMaUA
# Creating Defined Term node with ID: MoHYMCxx
# Creating Defined Term node with ID: BuHeJGZV
# Creating Defined Term node with ID: F6ZxWeOL
# Creating Defined Term node with ID: NhlFiJ9w
# Creating Defined Term node with ID: AibNEmKi
# Paragraph node created with ContextID: 3.3.2.(b), linked to parent Paragraph ContextID: 3.3.2
# Creating Named Entities for Paragraph ID: jA5pbr9q
# Creating Named Entity node with ID: sYKhV50D
# Creating Defined Terms for Paragraph ID: jA5pbr9q
# Creating Defined Term node with ID: pMJli1A7
# Creating Defined Term node with ID: aSV692ng
# Creating Defined Term node with ID: 1O9a5XJo
# Creating Defined Term node with ID: KmB670c1
# Creating Defined Term node with ID: 6xv9dbxD
# Creating Defined Term node with ID: dJ5CGR8d
# Paragraph node created with ContextID: 3.3.2.(c), linked to parent Paragraph ContextID: 3.3.2
# Creating Named Entities for Paragraph ID: fltpqOKq
# Creating Named Entity node with ID: l1csLKge
# Creating Named Entity node with ID: pu493vWo
# Creating Named Entity node with ID: 9HTZbtck
# Creating Named Entity node with ID: rjBJbXfc
# Creating Named Entity node with ID: LK7xbON6
# Creating Defined Terms for Paragraph ID: fltpqOKq
# Creating Defined Term node with ID: 145OHNIX
# Creating Defined Term node with ID: lWoAFDDo
# Creating Defined Term node with ID: C3OYCFvx
# Creating Defined Term node with ID: HwAPTGGj
# Creating Defined Term node with ID: nc02JcLs
# Creating Defined Term node with ID: TjT4vjpf
# Creating Defined Term node with ID: a8VVhrqu
# Creating Defined Term node with ID: T4uhQGC8
# Creating Defined Term node with ID: rhOU5SQ5
# Creating Defined Term node with ID: gIK4Ffis
# Paragraph node created with ContextID: 3.3.3, linked to parent Paragraph ContextID: 3.3
# Creating Named Entities for Paragraph ID: HZDFSKfM
# Creating Defined Terms for Paragraph ID: HZDFSKfM
# Paragraph node created with ContextID: 3.3.3.Guidance, linked to parent Paragraph ContextID: 3.3.3
# Creating Named Entities for Paragraph ID: mxvWKZXs
# Creating Defined Terms for Paragraph ID: mxvWKZXs
# Paragraph node created with ContextID: 3.3.3.Guidance.1, linked to parent Paragraph ContextID: 3.3.3.Guidance
# Creating Named Entities for Paragraph ID: tQMqH5jy
# Creating Named Entity node with ID: ou3vvMgF
# Creating Defined Terms for Paragraph ID: tQMqH5jy
# Creating Defined Term node with ID: Mozmbs9f
# Creating Defined Term node with ID: BAsZOw6x
# Paragraph node created with ContextID: 3.3.3.Guidance.2, linked to parent Paragraph ContextID: 3.3.3.Guidance
# Creating Named Entities for Paragraph ID: wda9FhRk
# Creating Named Entity node with ID: SrdNdNN6
# Creating Defined Terms for Paragraph ID: wda9FhRk
# Creating Defined Term node with ID: jmiATajd
# Creating Defined Term node with ID: vP3rlmJ2
# Creating Defined Term node with ID: R1V2CmS0
# Creating Defined Term node with ID: 29g7fZP7
# Paragraph node created with ContextID: 3.3.3.Guidance.3, linked to parent Paragraph ContextID: 3.3.3.Guidance
# Creating Named Entities for Paragraph ID: Svywog4B
# Creating Named Entity node with ID: KaAbbnKs
# Creating Defined Terms for Paragraph ID: Svywog4B
# Creating Defined Term node with ID: z8xvJdPU
# Creating Defined Term node with ID: PA24Llow
# Creating Defined Term node with ID: mhGwSnuK
# Creating Defined Term node with ID: S2dfg13k
# Creating Defined Term node with ID: xr01PZpp
# Creating Defined Term node with ID: iNtf3Swh
# Paragraph node created with ContextID: 3.3.4, linked to parent Paragraph ContextID: 3.3
# Creating Named Entities for Paragraph ID: 8PpKYKjE
# Creating Named Entity node with ID: ty11TY9b
# Creating Defined Terms for Paragraph ID: 8PpKYKjE
# Creating Defined Term node with ID: j7J2cONF
# Creating Defined Term node with ID: VCvND3oQ
# Creating Defined Term node with ID: tZo8UV3e
# Creating Defined Term node with ID: zzFq6CzI
# Creating Defined Term node with ID: InVjtOTf
# Creating Defined Term node with ID: o0wkDOUp
# Paragraph node created with ContextID: 3.4, linked to parent Paragraph ContextID: 3
# Creating Named Entities for Paragraph ID: BxZQQNwL
# Creating Defined Terms for Paragraph ID: BxZQQNwL
# Paragraph node created with ContextID: 3.4.1, linked to parent Paragraph ContextID: 3.4
# Creating Named Entities for Paragraph ID: ro4aejW0
# Creating Named Entity node with ID: k7z8MwrX
# Creating Named Entity node with ID: yeDCtUNm
# Creating Named Entity node with ID: YzZiNGHR
# Creating Defined Terms for Paragraph ID: ro4aejW0
# Creating Defined Term node with ID: pw3mwtkM
# Creating Defined Term node with ID: 3TPcSJRG
# Creating Defined Term node with ID: ICfqEhWQ
# Creating Defined Term node with ID: rD3439cJ
# Creating Defined Term node with ID: tWKCkrNi
# Creating Defined Term node with ID: qu12WCgF
# Creating Defined Term node with ID: TYTUEfQy
# Creating Defined Term node with ID: WDSwH1XY
# Creating Defined Term node with ID: cMeGgFsZ
# Creating Defined Term node with ID: qondxuAC
# Creating Defined Term node with ID: 50WYb4Pf
# Creating Defined Term node with ID: P8bPoJ2Y
# Creating Defined Term node with ID: vWW0Gso3
# Paragraph node created with ContextID: 3.4.2, linked to parent Paragraph ContextID: 3.4
# Creating Named Entities for Paragraph ID: wG6BmOIk
# ...
# Creating Named Entity node with ID: R4gUII9O
# Creating Named Entity node with ID: WtIRHbvN
# Creating Named Entity node with ID: SzFZmCt2
# Creating Defined Terms for Paragraph ID: 5uTrdO0W
# Creating Defined Term node with ID: wMgoIF7M
# Creating Defined Term node with ID: skv7ku3u
# Creating Defined Term node with ID: EKaRz0gM
# Creating Defined Term node with ID: 5qeTxUai
# Creating Defined Term node with ID: H8SJBDQN
# Creating Defined Term node with ID: fdCtEus7
# Paragraph node created with ContextID: 23.4.4, linked to parent Paragraph ContextID: 23.4
# Creating Named Entities for Paragraph ID: ccmh95FK
# Creating Named Entity node with ID: BJEIO2b7
# Creating Named Entity node with ID: ddX9k10f
# Creating Named Entity node with ID: Uq6kKVLp
# Creating Named Entity node with ID: tkjaOupV
# Creating Defined Terms for Paragraph ID: ccmh95FK
# Creating Defined Term node with ID: wJzZ7Jww
# Creating Defined Term node with ID: wHqgx6eM
# Creating Defined Term node with ID: 6TFCxxxD
# Creating Defined Term node with ID: ntibODWC
# Creating Defined Term node with ID: hs5epnoN
# Paragraph node created with ContextID: 23.4.5, linked to parent Paragraph ContextID: 23.4
# Creating Named Entities for Paragraph ID: IgpP5eST
# Creating Defined Terms for Paragraph ID: IgpP5eST
# Creating Defined Term node with ID: Qv7avThU
# Creating Defined Term node with ID: S63U0brk
# Paragraph node created with ContextID: 23.4.6, linked to parent Paragraph ContextID: 23.4
# Creating Named Entities for Paragraph ID: nt2trP09
# Creating Named Entity node with ID: p693ScpE
# Creating Named Entity node with ID: mCCiHxGo
# Creating Defined Terms for Paragraph ID: nt2trP09
# Creating Defined Term node with ID: dJZRwTZE
# Creating Defined Term node with ID: eFY3PPDT
# Creating Defined Term node with ID: 6UDxYc7N
# Creating Defined Term node with ID: HeyF7xIE
# Paragraph node created with ContextID: 23.4.7, linked to parent Paragraph ContextID: 23.4
# Creating Named Entities for Paragraph ID: fxWr98Js
# Creating Defined Terms for Paragraph ID: fxWr98Js
# Creating Defined Term node with ID: lAVWO8lf
# Creating Defined Term node with ID: S3ImjNnH
# Creating Defined Term node with ID: lI9dY3Xk
# Paragraph node created with ContextID: 23.4.8, linked to parent Paragraph ContextID: 23.4
# Creating Named Entities for Paragraph ID: WRiP7fk8
# Creating Defined Terms for Paragraph ID: WRiP7fk8
# Creating Defined Term node with ID: vmzBSa2f
# Creating Defined Term node with ID: xRU41ZTL
# Creating Defined Term node with ID: XofXLABf
# Creating Defined Term node with ID: 15QYjQQF
# Paragraph node created with ContextID: 23.4.8.Guidance, linked to parent Paragraph ContextID: 23.4.8
# Creating Named Entities for Paragraph ID: wt7wt4gL
# Creating Defined Terms for Paragraph ID: wt7wt4gL
# Paragraph node created with ContextID: 23.4.8.Guidance.1, linked to parent Paragraph ContextID: 23.4.8.Guidance
# Creating Named Entities for Paragraph ID: WjWFU4YV
# Creating Defined Terms for Paragraph ID: WjWFU4YV
# Creating Defined Term node with ID: 6Krj3JPG
# Creating Defined Term node with ID: uEOeRavF
# Creating Defined Term node with ID: 5n4UYhqV
# Creating Defined Term node with ID: NJA0UbNJ
# Paragraph node created with ContextID: 23.4.8.Guidance.2, linked to parent Paragraph ContextID: 23.4.8.Guidance
# Creating Named Entities for Paragraph ID: ni0nFnMz
# Creating Defined Terms for Paragraph ID: ni0nFnMz
# Creating Defined Term node with ID: m460Kmww
# Creating Defined Term node with ID: aK91Sdjs
# Paragraph node created with ContextID: 23.5, linked to parent Paragraph ContextID: 23
# Creating Named Entities for Paragraph ID: QPgW464a
# Creating Defined Terms for Paragraph ID: QPgW464a
# Paragraph node created with ContextID: 23.5.1, linked to parent Paragraph ContextID: 23.5
# Creating Named Entities for Paragraph ID: 2HgumD2A
# Creating Defined Terms for Paragraph ID: 2HgumD2A
# Creating Defined Term node with ID: RzCUyaXf
# Creating Defined Term node with ID: gHgSqZJF
# Creating Defined Term node with ID: UPfCxGWF
# Creating Defined Term node with ID: XflkPksA
# Creating Defined Term node with ID: RNkovIjt
# Paragraph node created with ContextID: 23.5.1.Guidance, linked to parent Paragraph ContextID: 23.5.1
# Creating Named Entities for Paragraph ID: wDBeXXBY
# Creating Defined Terms for Paragraph ID: wDBeXXBY
# Paragraph node created with ContextID: 23.5.1.Guidance.1, linked to parent Paragraph ContextID: 23.5.1.Guidance
# Creating Named Entities for Paragraph ID: 4Zd1qx5i
# Creating Defined Terms for Paragraph ID: 4Zd1qx5i
# Creating Defined Term node with ID: 2OWm2uaP
# Creating Defined Term node with ID: pAfO2tpB
# Creating Defined Term node with ID: fYQUni19
# Creating Defined Term node with ID: HcG2gYxs
# Creating Defined Term node with ID: wbXpeSaL
# Paragraph node created with ContextID: 23.5.1.Guidance.2, linked to parent Paragraph ContextID: 23.5.1.Guidance
# Creating Named Entities for Paragraph ID: cSb5rRWS
# Creating Defined Terms for Paragraph ID: cSb5rRWS
# Creating Defined Term node with ID: D14ARNaF
# Creating Defined Term node with ID: QFJBj0OR
# Creating Defined Term node with ID: kQ6FfU5J
# Creating Defined Term node with ID: KVQT9li1
# Creating Defined Term node with ID: UnhlFqov
# Paragraph node created with ContextID: 23.5.2, linked to parent Paragraph ContextID: 23.5
# Creating Named Entities for Paragraph ID: jB2hRxIg
# Creating Defined Terms for Paragraph ID: jB2hRxIg
# Creating Defined Term node with ID: v8YkDIyk
# Creating Defined Term node with ID: cPbxRBCW
# Creating Defined Term node with ID: rxePDA49
# Creating Defined Term node with ID: uDl7QUHB
# Creating Defined Term node with ID: sM26D5WX
# Paragraph node created with ContextID: 23.6, linked to parent Paragraph ContextID: 23
# Creating Named Entities for Paragraph ID: aH4v0wJV
# Creating Named Entity node with ID: d3oksOWY
# Creating Named Entity node with ID: ud3wCTnm
# Creating Named Entity node with ID: LmSUeEZw
# Creating Named Entity node with ID: SrmL8ANY
# Creating Named Entity node with ID: rDnoVluq
# Creating Defined Terms for Paragraph ID: aH4v0wJV
# Creating Defined Term node with ID: Z3WA2C5y
# Creating Defined Term node with ID: 8EQeYDd3
# Creating Defined Term node with ID: yvhN09yu
# Creating Defined Term node with ID: KFCCkcz6
# Creating Defined Term node with ID: qDV5049t
# Creating Defined Term node with ID: 1PUUwrFO
# Creating Defined Term node with ID: tNccXroq
# Creating Defined Term node with ID: XF0gLADt
# Paragraph node created with ContextID: 23.6.Guidance, linked to parent Paragraph ContextID: 23.6
# Creating Named Entities for Paragraph ID: qzHbrFR4
# Creating Defined Terms for Paragraph ID: qzHbrFR4
# Paragraph node created with ContextID: 23.6.Guidance.1, linked to parent Paragraph ContextID: 23.6.Guidance
# Creating Named Entities for Paragraph ID: e2hyu2Ku
# Creating Named Entity node with ID: OisNvCXa
# Creating Named Entity node with ID: g51ZbpXH
# Creating Named Entity node with ID: vEc8QYJz
# Creating Named Entity node with ID: uR8DCslA
# Creating Defined Terms for Paragraph ID: e2hyu2Ku
# Creating Defined Term node with ID: r397oyav
# Creating Defined Term node with ID: ZqffkMfm
# Creating Defined Term node with ID: OyJtMVuj
# Paragraph node created with ContextID: 23.6.Guidance.2, linked to parent Paragraph ContextID: 23.6.Guidance
# Creating Named Entities for Paragraph ID: ED3LPQ5Y
# Creating Named Entity node with ID: eQypwU7J
# Creating Named Entity node with ID: qNKq7q9Y
# Creating Named Entity node with ID: XHsKn5YT
# Creating Defined Terms for Paragraph ID: ED3LPQ5Y
# Creating Defined Term node with ID: bumIvn9g
# Creating Defined Term node with ID: YVPAE6VI
# Creating Defined Term node with ID: CDbPqhYG
# Paragraph node created with ContextID: 23.7, linked to parent Paragraph ContextID: 23
# Creating Named Entities for Paragraph ID: Ua2dQpna
# Creating Defined Terms for Paragraph ID: Ua2dQpna
# Creating Defined Term node with ID: sEoTIFAv
# Creating Defined Term node with ID: ZfiIjneA
# Paragraph node created with ContextID: 23.7.1, linked to parent Paragraph ContextID: 23.7
# Creating Named Entities for Paragraph ID: HudpGUAD
# Creating Named Entity node with ID: pqbB99ED
# Creating Named Entity node with ID: 6xjYiver
# Creating Named Entity node with ID: CtD7O7wl
# Creating Named Entity node with ID: b7yzn4N5
# Creating Defined Terms for Paragraph ID: HudpGUAD
# Creating Defined Term node with ID: vDJ090Ue
# Creating Defined Term node with ID: qLdo8of1
# Creating Defined Term node with ID: d0SB9NQG
# Creating Defined Term node with ID: 28GCeEBN
# Creating Defined Term node with ID: bfhKiK36
# Creating Defined Term node with ID: lwPR61RK
# Paragraph node created with ContextID: 23.7.2, linked to parent Paragraph ContextID: 23.7
# Creating Named Entities for Paragraph ID: isU2SpgS
# Creating Named Entity node with ID: KsPYjyBN
# Creating Named Entity node with ID: 0vYOR1Ug
# Creating Defined Terms for Paragraph ID: isU2SpgS
# Creating Defined Term node with ID: eODaeKTc
# Creating Defined Term node with ID: taQ9fopB
# Creating Defined Term node with ID: HMWNokqm
# Creating Defined Term node with ID: prlEOmip
# Creating Defined Term node with ID: LvvBTrOJ
# Paragraph node created with ContextID: 23.7.2.Guidance, linked to parent Paragraph ContextID: 23.7.2
# Creating Named Entities for Paragraph ID: VEZxyoxk
# Creating Defined Terms for Paragraph ID: VEZxyoxk
# Paragraph node created with ContextID: 23.7.2.Guidance.1, linked to parent Paragraph ContextID: 23.7.2.Guidance
# Creating Named Entities for Paragraph ID: yR974ouB
# Creating Named Entity node with ID: lY3d8BgY
# Creating Named Entity node with ID: 8xKStoAi
# Creating Named Entity node with ID: QEh7XbVG
# Creating Defined Terms for Paragraph ID: yR974ouB
# Creating Defined Term node with ID: Yh0OOd4g
# Paragraph node created with ContextID: 23.8, linked to parent Paragraph ContextID: 23
# Creating Named Entities for Paragraph ID: RMy3Zk2m
# Creating Named Entity node with ID: M0uOZHDa
# Creating Named Entity node with ID: j1lw8f3B
# Creating Named Entity node with ID: kLkfcHjf
# Creating Defined Terms for Paragraph ID: RMy3Zk2m
# Creating Defined Term node with ID: ZTwr6AOs
# Creating Defined Term node with ID: ERmDZkiL
# Creating Defined Term node with ID: CXMHVCij
# Paragraph node created with ContextID: 23.8.Guidance, linked to parent Paragraph ContextID: 23.8
# Creating Named Entities for Paragraph ID: y2gNJKQl
# Creating Defined Terms for Paragraph ID: y2gNJKQl
# Paragraph node created with ContextID: 23.8.Guidance.1, linked to parent Paragraph ContextID: 23.8.Guidance
# Creating Named Entities for Paragraph ID: A37jkN08
# Creating Named Entity node with ID: Q625v8FB
# Creating Named Entity node with ID: vDQrx2BR
# Creating Named Entity node with ID: l6Qw50oQ
# Creating Defined Terms for Paragraph ID: A37jkN08
# Creating Defined Term node with ID: 2pZDQBLM
# Creating Defined Term node with ID: pFe0zih6
# Paragraph node created with ContextID: 23.8.Guidance.2, linked to parent Paragraph ContextID: 23.8.Guidance
# Creating Named Entities for Paragraph ID: saFvF4J5
# Creating Named Entity node with ID: q1TQWCnd
# Creating Named Entity node with ID: 50QDF7mF
# Creating Defined Terms for Paragraph ID: saFvF4J5
# Creating Defined Term node with ID: 6U6SShsu
# Paragraph node created with ContextID: 23.9, linked to parent Paragraph ContextID: 23
# Creating Named Entities for Paragraph ID: Vm4uzhBf
# Creating Defined Terms for Paragraph ID: Vm4uzhBf
# Creating Defined Term node with ID: AIRGHp3y
# Creating Defined Term node with ID: x59YEIcK
# Creating Defined Term node with ID: nc1jx89Q
# Creating Defined Term node with ID: U4fIJZJm
# Creating Defined Term node with ID: 7hBPLxkP
# Paragraph node created with ContextID: 23.10, linked to parent Paragraph ContextID: 23
# Creating Named Entities for Paragraph ID: rtNm9yas
# Creating Defined Terms for Paragraph ID: rtNm9yas
# Paragraph node created with ContextID: 23.10.1, linked to parent Paragraph ContextID: 23.10
# Creating Named Entities for Paragraph ID: JC0hlCql
# Creating Named Entity node with ID: htHDDZbG
# Creating Named Entity node with ID: y7Sx0ZrB
# Creating Named Entity node with ID: xmSINvqN
# Creating Defined Terms for Paragraph ID: JC0hlCql
# Creating Defined Term node with ID: KJBOMlac
# Creating Defined Term node with ID: Z2twu0Aa
# Creating Defined Term node with ID: LaczuAAN
# Creating Defined Term node with ID: ZUrLJHBw
# Creating Defined Term node with ID: QP6ZWbel
# Paragraph node created with ContextID: 23.10.2, linked to parent Paragraph ContextID: 23.10
# Creating Named Entities for Paragraph ID: v1F53BkM
# Creating Defined Terms for Paragraph ID: v1F53BkM
# Creating Defined Term node with ID: f2zcHcHA
# Creating Defined Term node with ID: db0QrJFw
# Creating Defined Term node with ID: 57vcj6Da
# Creating Defined Term node with ID: BZzI6sDJ
# Paragraph node created with ContextID: 23.10.3, linked to parent Paragraph ContextID: 23.10
# Creating Named Entities for Paragraph ID: Rp4VywfK
# Creating Named Entity node with ID: YFm24uLz
# Creating Defined Terms for Paragraph ID: Rp4VywfK
# Creating Defined Term node with ID: skpPNotq
# Creating Defined Term node with ID: Zbem6QvJ
# Creating Defined Term node with ID: m2bSfMdw
# Paragraph node created with ContextID: 23.10.3.Guidance, linked to parent Paragraph ContextID: 23.10.3
# Creating Named Entities for Paragraph ID: 3O0FiMix
# Creating Defined Terms for Paragraph ID: 3O0FiMix
# Paragraph node created with ContextID: 23.10.3.Guidance.1, linked to parent Paragraph ContextID: 23.10.3.Guidance
# Creating Named Entities for Paragraph ID: AKzhhr7Z
# Creating Named Entity node with ID: l3pOGxV1
# Creating Defined Terms for Paragraph ID: AKzhhr7Z
# Creating Defined Term node with ID: PXBCaffV
# Creating Defined Term node with ID: rffHBWdL
# Creating Defined Term node with ID: IHSJ6gz4
# Creating Defined Term node with ID: Td68tDAt
# Creating Defined Term node with ID: Vumzm65K
# Paragraph node created with ContextID: 23.11, linked to parent Paragraph ContextID: 23
# Creating Named Entities for Paragraph ID: 4sNNQECl
# Creating Named Entity node with ID: sWc7IqjC
# Creating Named Entity node with ID: KtgJNYW3
# Creating Defined Terms for Paragraph ID: 4sNNQECl
# Creating Defined Term node with ID: n9jzILEM
# Creating Defined Term node with ID: iWMWAbsw
# Creating Defined Term node with ID: 2kmduCwP
# Creating Defined Term node with ID: kdvdGOXo
# Paragraph node created with ContextID: 23.12, linked to parent Paragraph ContextID: 23
# Creating Named Entities for Paragraph ID: u3v3iwU5
# Creating Defined Terms for Paragraph ID: u3v3iwU5
# Creating Defined Term node with ID: AmJVreAV
# Paragraph node created with ContextID: 23.12.1, linked to parent Paragraph ContextID: 23.12
# Creating Named Entities for Paragraph ID: fBb8VIUG
# Creating Named Entity node with ID: WEImzrbx
# Creating Named Entity node with ID: 9r8wcVyB
# Creating Named Entity node with ID: PvMGYUHx
# Creating Named Entity node with ID: pLXfGADP
# Creating Named Entity node with ID: uLUfFsHH
# Creating Defined Terms for Paragraph ID: fBb8VIUG
# Creating Defined Term node with ID: PGz3ZOmu
# Creating Defined Term node with ID: KO91et1Z
# Creating Defined Term node with ID: AmDJEK2K
# Creating Defined Term node with ID: W37EwVZc
# Paragraph node created with ContextID: 23.12.2, linked to parent Paragraph ContextID: 23.12
# Creating Named Entities for Paragraph ID: E9sFAHKU
# Creating Named Entity node with ID: UepfKwUZ
# Creating Named Entity node with ID: 6FWwNU6F
# Creating Defined Terms for Paragraph ID: E9sFAHKU
# Creating Defined Term node with ID: g0jqs5ex
# Creating Defined Term node with ID: NiwvC2m6
# Creating Defined Term node with ID: 68MLbiIA
# Creating Defined Term node with ID: Rvp9zM6M
# Creating Defined Term node with ID: 0m24FJ14
# Creating Defined Term node with ID: GwTXlpXm
# Creating Defined Term node with ID: gLtMSwM4
# Creating Defined Term node with ID: Md9oWBGh
# Creating Defined Term node with ID: zeMBmHNe
# Paragraph node created with ContextID: 23.12.3, linked to parent Paragraph ContextID: 23.12
# Creating Named Entities for Paragraph ID: cxfpAiti
# Creating Named Entity node with ID: VOlURU5X
# Creating Named Entity node with ID: lqOyigtR
# Creating Defined Terms for Paragraph ID: cxfpAiti
# Creating Defined Term node with ID: fJ0Z0sOz
# Creating Defined Term node with ID: 9SjGWcz4
# Creating Defined Term node with ID: 664T0KUA
# Creating Defined Term node with ID: RnN0JUsh
# Connection to Neo4j closed.
